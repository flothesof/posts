# %% [markdown]
# Link to JakeVDP's presentation: [https://speakerdeck.com/jakevdp/altair-declarative-visualization-in-python-dse-summit-2016](https://speakerdeck.com/jakevdp/altair-declarative-visualization-in-python-dse-summit-2016)

# %%
import altair

# %%
altair.tutorial()
# Out:
# Copying notebooks into fresh tutorial directory: ./AltairTutorial
# Click on the following notebooks to explore the tutorial:
# ./AltairTutorial/
#   01-Index.ipynb
#   02-Introduction.ipynb
#   03-ScatterCharts.ipynb
#   04-BarCharts.ipynb
#   05-LineCharts.ipynb
#   06-AreaCharts.ipynb
#   07-LayeredCharts.ipynb
#   08-GroupedRegressionCharts.ipynb
#   09-CarsDataset.ipynb
#   10-IrisPairgrid.ipynb
#   example.html
# ./AltairTutorial/auto_examples/
#   area.ipynb
#   area_vertical.ipynb
#   bar_1d.ipynb
#   bar_aggregate.ipynb
#   bar_aggregate_size.ipynb
#   bar_aggregate_vertical.ipynb
#   bar_grouped.ipynb
#   bar_grouped_horizontal.ipynb
#   bar_layered_transparent.ipynb
#   bar_yearmonth.ipynb
#   bubble_health_income.ipynb
#   circle.ipynb
#   github_punchcard.ipynb
#   histogram.ipynb
#   Index.ipynb
#   layer_histogram.ipynb
#   layer_line_color_rule.ipynb
#   line.ipynb
#   line_color.ipynb
#   line_detail.ipynb
#   line_monotone.ipynb
#   line_month.ipynb
#   line_slope.ipynb
#   line_step.ipynb
#   point_1d.ipynb
#   point_dot_timeunit_color.ipynb
#   point_filled.ipynb
#   scatter.ipynb
#   scatter_aggregate_detail.ipynb
#   scatter_binned.ipynb
#   scatter_binned_color.ipynb
#   scatter_binned_size.ipynb
#   scatter_bubble.ipynb
#   scatter_color.ipynb
#   scatter_color_custom.ipynb
#   scatter_color_order.ipynb
#   scatter_color_ordinal.ipynb
#   scatter_color_ordinal_custom.ipynb
#   scatter_color_quantitative.ipynb
#   scatter_color_shape_constant.ipynb
#   scatter_colored_with_shape.ipynb
#   scatter_connected.ipynb
#   scatter_opacity.ipynb
#   square.ipynb
#   stacked_area.ipynb
#   stacked_area_normalize.ipynb
#   stacked_area_ordinal.ipynb
#   stacked_area_stream.ipynb
#   stacked_bar_1d.ipynb
#   stacked_bar_h.ipynb
#   stacked_bar_h_order.ipynb
#   stacked_bar_normalize.ipynb
#   stacked_bar_population.ipynb
#   stacked_bar_size.ipynb
#   stacked_bar_sum_opacity.ipynb
#   stacked_bar_v.ipynb
#   stacked_bar_weather.ipynb
#   text_scatter_colored.ipynb
#   text_table_heatmap.ipynb
#   tick_dot.ipynb
#   tick_dot_thickness.ipynb
#   tick_strip.ipynb
#   trellis_anscombe.ipynb
#   trellis_bar.ipynb
#   trellis_bar_histogram.ipynb
#   trellis_barley.ipynb
#   trellis_row_column.ipynb
#   trellis_scatter.ipynb
#   trellis_scatter_binned_row.ipynb
#   trellis_stacked_bar.ipynb

# %%
from altair import datasets

# %%
datasets.list_datasets()
# Out:
# ['flights-airport',
#  'wheat',
#  'unemployment-across-industries',
#  'gapminder',
#  'stocks',
#  'burtin',
#  'gapminder-health-income',
#  'world-110m',
#  'weball26',
#  'points',
#  'monarchs',
#  'airports',
#  'flare',
#  'seattle-weather',
#  'flights-3m',
#  'climate',
#  'driving',
#  'seattle-temps',
#  'jobs',
#  'barley',
#  'cars',
#  'budgets',
#  'crimea',
#  'budget',
#  'population',
#  'github',
#  'weather',
#  'anscombe',
#  'us-10m',
#  'miserables',
#  'birdstrikes',
#  'countries',
#  'movies',
#  'flights-10k',
#  'sf-temps',
#  'iris',
#  'flights-20k',
#  'flights-5k',
#  'sp500',
#  'flights-2k']

# %%
cars = datasets.load_dataset('cars')

# %%
cars.head()
# Out:
#    Acceleration  Cylinders  Displacement  Horsepower  Miles_per_Gallon  \
# 0          12.0          8         307.0       130.0              18.0
# 1          11.5          8         350.0       165.0              15.0
# 2          11.0          8         318.0       150.0              18.0
# 3          12.0          8         304.0       150.0              16.0
# 4          10.5          8         302.0       140.0              17.0
#
#                         Name Origin  Weight_in_lbs        Year
# 0  chevrolet chevelle malibu    USA           3504  1970-01-01
# 1          buick skylark 320    USA           3693  1970-01-01
# 2         plymouth satellite    USA           3436  1970-01-01
# 3              amc rebel sst    USA           3433  1970-01-01
# 4                ford torino    USA           3449  1970-01-01

# %%
from altair import Chart

# %%
Chart(cars).mark_circle().encode(x='Weight_in_lbs', y='Horsepower', color='Origin')
# Out:
# <div class="vega-embed" id="f21ad2b9-92ee-4cee-b5bf-ea5ae21bc69f"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %%
Chart(cars).mark_circle().encode(x='Weight_in_lbs', y='Horsepower', color='Cylinders:N')
# Out:
# <div class="vega-embed" id="e0a56ef7-f746-4f75-8654-f9b2ad51d574"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %%
Chart(cars).mark_circle().encode(x='Weight_in_lbs', y='Horsepower', color='Origin')
# Out:
# <div class="vega-embed" id="13620b33-51c3-4cb1-9190-58afba481341"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %%
Chart(cars).mark_circle().encode(x='Weight_in_lbs', y='Horsepower', color='Cylinders', row='Origin').configure_cell(height=150)
# Out:
# <div class="vega-embed" id="c1de7106-4e74-4365-bb33-53f197f347af"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>
