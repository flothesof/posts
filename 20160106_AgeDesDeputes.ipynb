# %% [markdown]
# Dans ce billet, je calcule la moyenne d'âge des députés français (c'est-à-dire les élus qui représentent les français à l'assemblée nationale, à ne pas confondre avec les sénateurs). Je me sers pour cela d'un document disponible sur le site de l'assemblée nationale, en PDF. J'en extrais les textes puis les traite afin de tracer un histogramme à l'aide du package d'analyse de données pour Python `pandas`.

# %% [markdown]
# # Introduction

# %% [markdown]
# Pourquoi calculer l'âge moyen des députés ? Bonne question : l'idée m'est venue suite à la lecture de ce tweet.

# %% [markdown]
# <blockquote class="twitter-tweet" lang="en"><p lang="fr" dir="ltr">La moyennz d&#39;âge des députés et sénateurs français est de 65 ans ! STOP ! Place à la jeunesse !</p>&mdash; Geof&#39;☭ (@DebailleuxG) <a href="https://twitter.com/DebailleuxG/status/683281096822374401">January 2, 2016</a></blockquote>
# <script async src="//platform.twitter.com/widgets.js" charset="utf-8"></script>

# %% [markdown]
# Comment savoir si ce qui est affirmé ici est vrai ou pas ? Je me concentre ici sur une réponse partielle : calculer l'âge moyen des députés et plus exactement leur distribution.
#
# Ca tombe bien, car l'assemblée nationale met à disposition une liste alphabétique en PDF [ici](http://www2.assemblee-nationale.fr/static/tribun/trombinoscope/trombinoscope_alpha.pdf). Nous allons nous en servir pour calculer la distribution des âges.

# %% [markdown]
# # Conversion du PDF en texte

# %% [markdown]
# Il s'agit tout d'abord de convertir le fichier PDF en fichier texte brut. Je me sers ici de `pdftotext`, un utilitaire que l'on peut utiliser en ligne de commande.

# %%
# !pdftotext.exe
# Out:
# pdftotext version 3.04
# Copyright 1996-2014 Glyph & Cog, LLC
# Usage: pdftotext [options] <PDF-file> [<text-file>]
#   -f <int>             : first page to convert
#   -l <int>             : last page to convert
#   -layout              : maintain original physical layout
#   -table               : similar to -layout, but optimized for tables
#   -lineprinter         : use strict fixed-pitch/height layout
#   -raw                 : keep strings in content stream order
#   -fixed <fp>          : assume fixed-pitch (or tabular) text
#   -linespacing <fp>    : fixed line spacing for LinePrinter mode
#   -clip                : separate clipped text
#   -enc <string>        : output text encoding name
#   -eol <string>        : output end-of-line convention (unix, dos, or mac)
#   -nopgbrk             : don't insert page breaks between pages
#   -opw <string>        : owner password (for encrypted files)
#   -upw <string>        : user password (for encrypted files)
#   -q                   : don't print any messages or errors
#   -cfg <string>        : configuration file to use in place of .xpdfrc
#   -v                   : print copyright and version info
#   -h                   : print usage information
#   -help                : print usage information
#   --help               : print usage information
#   -?                   : print usage information

# %% [markdown]
# Après avoir lu l'aide, on peut convertir le fichier PDF en texte à l'aide de la commande suivante.

# %%
# !pdftotext.exe trombinoscope_alpha.pdf

# %% [markdown]
# Comment s'appelle le fichier créé ?

# %%
# !dir
# Out:
#  Le volume dans le lecteur C s'appelle Windows7
#  Le num‚ro de s‚rie du volume est C299-2D6F
#
#  R‚pertoire de C:\Users\FL232714\Documents\Perso\D‚put‚s
#
# 07/01/2016  16:08    <REP>          .
# 07/01/2016  16:08    <REP>          ..
# 07/01/2016  15:50    <REP>          .ipynb_checkpoints
# 07/01/2016  16:08           248ÿ363 20160106_AgeDesDeputes.ipynb
# 28/05/2014  11:50         1ÿ179ÿ648 pdftotext.exe
# 06/01/2016  13:22        16ÿ648ÿ365 trombinoscope_alpha.pdf
# 07/01/2016  16:08           155ÿ941 trombinoscope_alpha.txt
#                4 fichier(s)       18ÿ232ÿ317 octets
#                3 R‚p(s)  14ÿ458ÿ183ÿ680 octets libres

# %% [markdown]
# Lisons maintenant le fichier texte créé pour en extraire les noms des députés et les dates de naissance.

# %% [markdown]
# # Extraction du texte

# %% [markdown]
# ## Travail sur fragment

# %% [markdown]
# Après avoir regardé le contenu du fichier texte au bloc note, je me suis rendu compte que les noms et dates de naissance sont dans le désordre. Pas de problème, on va lire ça avec des expressions régulières et on va voir si on arrive à trouver ce qu'on cherche ! On va travailler sur la première page dans un premier temps (on commence petit avant d'étendre la méthode au document entier) :

# %%
first_page = """Ain - Circonscription n° 5
M. Damien Abad

Val-de-Marne - Circonscription n° 6
Mme Laurence Abeille

Les Républicains Né le 5 avril 1980 à Nîmes (Gard) Secrétaire d'âge de l'Assemblée nationale
Président du conseil départemental (Ain) Élu à l'Assemblée nationale le 20 juin 2012
Mayotte - Circonscription n° 2
M. Ibrahim Aboubacar

Écologiste Née le 17 juin 1960 à Neuilly-sur-Seine (Hauts-de-Seine)
Cadre du secteur privé Élue à l'Assemblée nationale le 20 juin 2012
Hérault - Circonscription n° 6
M. Élie Aboud

Socialiste, républicain et citoyen Né le 1erfévrier 1965 à Fomboni (Comores)
Ingénieur des travaux publics Élu à l'Assemblée nationale le 20 juin 2012
Haute-Savoie - Circonscription n° 1
M. Bernard Accoyer

Les Républicains Né le 12 octobre 1959 à Beyrouth (Liban)
Médecin cardiologue (Chef de service) Adjoint au Maire de Béziers Élu à l'Assemblée nationale le 20 juin 2007 Réélu le 16 décembre 2012
Finistère - Circonscription n° 2
Mme Patricia Adam

Les Républicains Né le 12 août 1945 à Lyon (Rhône)

Socialiste, républicain et citoyen Née le 15 avril 1953 à Saint-Cloud (Hauts-de-Seine)

Médecin ORL
Maire d'Annecy-le-Vieux
Élu à l'Assemblée nationale le 28 mars 1993 Réélu les 1erjuin 1997, 16 juin 2002, 20 juin 2007 et 20 juin 2012

Cadre d'action sociale Élue à l'Assemblée nationale le 16 juin 2002 Réélue les 20 juin 2007 et 20 juin 2012

15"""

# %% [markdown]
# Construisons d'abord une expression régulière pour les prénoms :

# %%
import re

# %%
p = re.compile("^(M\.|Mme)((\s[\w\-]+)+)", re.MULTILINE)

# %%
p.findall(first_page)
# Out:
# [('M.', ' Damien Abad', ' Abad'),
#  ('Mme', ' Laurence Abeille', ' Abeille'),
#  ('M.', ' Ibrahim Aboubacar', ' Aboubacar'),
#  ('M.', ' Élie Aboud', ' Aboud'),
#  ('M.', ' Bernard Accoyer', ' Accoyer'),
#  ('Mme', ' Patricia Adam', ' Adam')]

# %% [markdown]
# On peut maintenant passer aux dates de naissance :

# %%
p2 = re.compile('Né[e]* le (\d+(\s|er|eme)[a-z\u00E0-\u00FC]+ \d+)', re.MULTILINE)

# %%
p2.findall(first_page)
# Out:
# [('5 avril 1980', ' '),
#  ('17 juin 1960', ' '),
#  ('1erfévrier 1965', 'er'),
#  ('12 octobre 1959', ' '),
#  ('12 août 1945', ' '),
#  ('15 avril 1953', ' ')]

# %% [markdown]
# L'expression régulière trouvée est un peu compliquée à cause de la présence de date écrite sous la forme `1er février`.

# %% [markdown]
# ## Extraction du texte complet

# %% [markdown]
# Maintenant que la première page donne des résultats valides, passons au texte complet.

# %%
text = open('trombinoscope_alpha.txt').read()

# %%
names = p.findall(text)
names
# Out:
# [('M.', ' Damien Abad', ' Abad'),
#  ('Mme', ' Laurence Abeille', ' Abeille'),
#  ('M.', ' Ibrahim Aboubacar', ' Aboubacar'),
#  ('M.', ' Élie Aboud', ' Aboud'),
#  ('M.', ' Bernard Accoyer', ' Accoyer'),
#  ('Mme', ' Patricia Adam', ' Adam'),
#  ('Mme', ' Sylviane Alaux', ' Alaux'),
#  ('M.', ' Éric Alauzet', ' Alauzet'),
#  ('M.', ' Yves Albarello', ' Albarello'),
#  ('Mme', ' Brigitte Allain', ' Allain'),
#  ('M.', ' Jean-Pierre Allossery', ' Allossery'),
#  ('Mme', ' Nicole Ameline', ' Ameline'),
#  ('M.', ' Pouria Amirshahi', ' Amirshahi'),
#  ('M.', ' François André', ' André'),
#  ('Mme', ' Sylvie Andrieux', ' Andrieux'),
#  ('M.', ' Benoist Apparu', ' Apparu'),
#  ('Mme', ' Nathalie Appéré', ' Appéré'),
#  ('M.', ' Kader Arif', ' Arif'),
#  ('Mme', ' Laurence Arribagé', ' Arribagé'),
#  ('M.', ' François Asensi', ' Asensi'),
#  ('M.', ' Christian Assaf', ' Assaf'),
#  ('Mme', ' Isabelle Attard', ' Attard'),
#  ('M.', ' Julien Aubert', ' Aubert'),
#  ('M.', ' Olivier Audibert Troin', ' Troin'),
#  ('Mme', ' Danielle Auroi', ' Auroi'),
#  ('M.', ' Pierre Aylagas', ' Aylagas'),
#  ('M.', ' Jean-Marc Ayrault', ' Ayrault'),
#  ('M.', ' Bruno Nestor Azerot', ' Azerot'),
#  ('M.', ' Alexis Bachelay', ' Bachelay'),
#  ('M.', ' Guillaume Bachelay', ' Bachelay'),
#  ('M.', ' Jean-Paul Bacquet', ' Bacquet'),
#  ('M.', ' Dominique Baert', ' Baert'),
#  ('M.', ' Guy Bailliart', ' Bailliart'),
#  ('M.', ' Patrick Balkany', ' Balkany'),
#  ('M.', ' Gérard Bapt', ' Bapt'),
#  ('M.', ' Frédéric Barbier', ' Barbier'),
#  ('M.', ' Jean-Pierre Barbier', ' Barbier'),
#  ('M.', ' Serge Bardy', ' Bardy'),
#  ('Mme', ' Ericka Bareigts', ' Bareigts'),
#  ('M.', ' Claude Bartolone', ' Bartolone'),
#  ('M.', ' Christian Bataille', ' Bataille'),
#  ('Mme', ' Delphine Batho', ' Batho'),
#  ('Mme', ' Marie-Noëlle Battistel', ' Battistel'),
#  ('M.', ' Laurent Baumel', ' Baumel'),
#  ('M.', ' Philippe Baumel', ' Baumel'),
#  ('M.', ' Denis Baupin', ' Baupin'),
#  ('M.', ' Nicolas Bays', ' Bays'),
#  ('Mme', ' Catherine Beaubatie', ' Beaubatie'),
#  ('Mme', ' Marie-Françoise Bechtel', ' Bechtel'),
#  ('M.', ' Jean-Marie Beffara', ' Beffara'),
#  ('Mme', ' Huguette Bello', ' Bello'),
#  ('M.', ' Luc Belot', ' Belot'),
#  ('M.', ' Jacques Alain Bénisti', ' Bénisti'),
#  ('M.', ' Thierry Benoit', ' Benoit'),
#  ('Mme', ' Karine Berger', ' Berger'),
#  ('M.', ' Sylvain Berrios', ' Berrios'),
#  ('Mme', ' Chantal Berthelot', ' Berthelot'),
#  ('M.', ' Xavier Bertrand', ' Bertrand'),
#  ('Mme', ' Véronique Besse', ' Besse'),
#  ('Mme', ' Gisèle Biémouret', ' Biémouret'),
#  ('M.', ' Philippe Bies', ' Bies'),
#  ('M.', ' Erwann Binet', ' Binet'),
#  ('M.', ' Étienne Blanc', ' Blanc'),
#  ('M.', ' Jean-Pierre Blazy', ' Blazy'),
#  ('M.', ' Yves Blein', ' Blein'),
#  ('M.', ' Jean-Luc Bleunven', ' Bleunven'),
#  ('M.', ' Patrick Bloche', ' Bloche'),
#  ('M.', ' Alain Bocquet', ' Bocquet'),
#  ('M.', ' Daniel Boisserie', ' Boisserie'),
#  ('M.', ' Jacques Bompard', ' Bompard'),
#  ('Mme', ' Michèle Bonneton', ' Bonneton'),
#  ('M.', ' Marcel Bonnot', ' Bonnot'),
#  ('M.', ' Christophe Borgel', ' Borgel'),
#  ('M.', ' Jean-Claude Bouchet', ' Bouchet'),
#  ('M.', ' Florent Boudié', ' Boudié'),
#  ('Mme', ' Marie-Odile Bouillé', ' Bouillé'),
#  ('M.', ' Christophe Bouillon', ' Bouillon'),
#  ('M.', ' Gilles Bourdouleix', ' Bourdouleix'),
#  ('Mme', ' Brigitte Bourguignon', ' Bourguignon'),
#  ('M.', ' Malek Boutih', ' Boutih'),
#  ('Mme', ' Kheira Bouziane-Laroussi', ' Bouziane-Laroussi'),
#  ('Mme', ' Valérie Boyer', ' Boyer'),
#  ('M.', ' Emeric Bréhier', ' Bréhier'),
#  ('M.', ' Xavier Breton', ' Breton'),
#  ('M.', ' Philippe Briand', ' Briand'),
#  ('M.', ' Jean-Louis Bricout', ' Bricout'),
#  ('M.', ' Jean-Jacques Bridey', ' Bridey'),
#  ('M.', ' Bernard Brochand', ' Brochand'),
#  ('Mme', ' Isabelle Bruneau', ' Bruneau'),
#  ('Mme', ' Marie-George Buffet', ' Buffet'),
#  ('M.', ' Gwenegan Bui', ' Bui'),
#  ('Mme', ' Sabine Buis', ' Buis'),
#  ('M.', ' Jean-Claude Buisine', ' Buisine'),
#  ('Mme', ' Sylviane Bulteau', ' Bulteau'),
#  ('M.', ' Vincent Burroni', ' Burroni'),
#  ('M.', ' Dominique Bussereau', ' Bussereau'),
#  ('M.', ' Alain Calmette', ' Calmette'),
#  ('M.', ' Jean-Christophe Cambadélis', ' Cambadélis'),
#  ('M.', ' Jean-Jacques Candelier', ' Candelier'),
#  ('Mme', ' Colette Capdevielle', ' Capdevielle'),
#  ('M.', ' Yann Capet', ' Capet'),
#  ('M.', ' Christophe Caresche', ' Caresche'),
#  ('Mme', ' Marie-Arlette Carlotti', ' Carlotti'),
#  ('M.', ' Jean-Noël Carpentier', ' Carpentier'),
#  ('M.', ' Olivier Carré', ' Carré'),
#  ('Mme', ' Fanélie Carrey-Conte', ' Carrey-Conte'),
#  ('M.', ' Gilles Carrez', ' Carrez'),
#  ('Mme', ' Martine Carrillon-Couvreur', ' Carrillon-Couvreur'),
#  ('M.', ' Patrice Carvalho', ' Carvalho'),
#  ('M.', ' Christophe Castaner', ' Castaner'),
#  ('M.', ' Laurent Cathala', ' Cathala'),
#  ('M.', ' Jean-Yves Caullet', ' Caullet'),
#  ('M.', ' Christophe Cavard', ' Cavard'),
#  ('M.', ' Yves Censi', ' Censi'),
#  ('Mme', ' Nathalie Chabanne', ' Chabanne'),
#  ('M.', ' Ary Chalus', ' Chalus'),
#  ('M.', ' Guy Chambefort', ' Chambefort'),
#  ('M.', ' Jean-Paul Chanteguet', ' Chanteguet'),
#  ('Mme', ' Marie-Anne Chapdelaine', ' Chapdelaine'),
#  ('M.', ' Gérard Charasse', ' Charasse'),
#  ('M.', ' Gaby Charroux', ' Charroux'),
#  ('M.', ' Jérôme Chartier', ' Chartier'),
#  ('M.', ' André Chassaigne', ' Chassaigne'),
#  ('M.', ' Luc Chatel', ' Chatel'),
#  ('M.', ' Guy-Michel Chauveau', ' Chauveau'),
#  ('Mme', ' Dominique Chauvel', ' Chauvel'),
#  ('M.', ' Pascal Cherki', ' Cherki'),
#  ('M.', ' Gérard Cherpion', ' Cherpion'),
#  ('M.', ' Guillaume Chevrollier', ' Chevrollier'),
#  ('M.', ' Alain Chrétien', ' Chrétien'),
#  ('M.', ' Jean-Louis Christ', ' Christ'),
#  ('M.', ' Dino Cinieri', ' Cinieri'),
#  ('M.', ' Jean-David Ciot', ' Ciot'),
#  ('M.', ' Éric Ciotti', ' Ciotti'),
#  ('M.', ' Alain Claeys', ' Claeys'),
#  ('M.', ' Stéphane Claireaux', ' Claireaux'),
#  ('M.', ' Jean-Michel Clément', ' Clément'),
#  ('Mme', ' Marie-Françoise Clergeau', ' Clergeau'),
#  ('M.', ' Philippe Cochet', ' Cochet'),
#  ('M.', ' Romain Colas', ' Colas'),
#  ('M.', ' Gilbert Collard', ' Collard'),
#  ('M.', ' David Comet', ' Comet'),
#  ('M.', ' Jean-François Copé', ' Copé'),
#  ('M.', ' Philip Cordery', ' Cordery'),
#  ('M.', ' François Cornut-Gentille', ' Cornut-Gentille'),
#  ('M.', ' Sergio Coronado', ' Coronado'),
#  ('Mme', ' Valérie Corre', ' Corre'),
#  ('M.', ' Jean-Louis Costes', ' Costes'),
#  ('M.', ' Jean-Jacques Cottel', ' Cottel'),
#  ('M.', ' Charles de Courson', ' Courson'),
#  ('M.', ' Édouard Courtial', ' Courtial'),
#  ('Mme', ' Catherine Coutelle', ' Coutelle'),
#  ('M.', ' Jean-Michel Couve', ' Couve'),
#  ('M.', ' Jacques Cresta', ' Cresta'),
#  ('Mme', ' Pascale Crozon', ' Crozon'),
#  ('M.', ' Frédéric Cuvillier', ' Cuvillier'),
#  ('M.', ' Carlos Da Silva', ' Silva'),
#  ('Mme', ' Seybah Dagoma', ' Dagoma'),
#  ('Mme', ' Marie-Christine Dalloz', ' Dalloz'),
#  ('M.', ' Yves Daniel', ' Daniel'),
#  ('M.', ' Gérald Darmanin', ' Darmanin'),
#  ('M.', ' Olivier Dassault', ' Dassault'),
#  ('M.', ' Marc-Philippe Daubresse', ' Daubresse'),
#  ('M.', ' Bernard Debré', ' Debré'),
#  ('M.', ' Jean-Pierre Decool', ' Decool'),
#  ('M.', ' Bernard Deflesselles', ' Deflesselles'),
#  ('M.', ' Laurent Degallaix', ' Degallaix'),
#  ('M.', ' Lucien Degauchy', ' Degauchy'),
#  ('M.', ' Pascal Deguilhem', ' Deguilhem'),
#  ('M.', ' Rémi Delatte', ' Delatte'),
#  ('Mme', ' Florence Delaunay', ' Delaunay'),
#  ('Mme', ' Michèle Delaunay', ' Delaunay'),
#  ('M.', ' Guy Delcourt', ' Delcourt'),
#  ('Mme', ' Carole Delga', ' Delga'),
#  ('M.', ' Pascal Demarthe', ' Demarthe'),
#  ('M.', ' Stéphane Demilly', ' Demilly'),
#  ('M.', ' Sébastien Denaja', ' Denaja'),
#  ('Mme', ' Françoise Descamps-Crosnier', ' Descamps-Crosnier'),
#  ('Mme', ' Sophie Dessus', ' Dessus'),
#  ('M.', ' Jean-Louis Destans', ' Destans'),
#  ('M.', ' Michel Destot', ' Destot'),
#  ('M.', ' Patrick Devedjian', ' Devedjian'),
#  ('M.', ' Nicolas Dhuicq', ' Dhuicq'),
#  ('Mme', ' Sophie Dion', ' Dion'),
#  ('M.', ' Marc Dolez', ' Dolez'),
#  ('Mme', ' Fanny Dombre Coste', ' Coste'),
#  ('M.', ' Jean-Pierre Door', ' Door'),
#  ('M.', ' Dominique Dord', ' Dord'),
#  ('M.', ' René Dosière', ' Dosière'),
#  ('M.', ' Philippe Doucet', ' Doucet'),
#  ('Mme', ' Sandrine Doucet', ' Doucet'),
#  ('M.', ' David Douillet', ' Douillet'),
#  ('Mme', ' Jeanine Dubié', ' Dubié'),
#  ('Mme', ' Françoise Dubois', ' Dubois'),
#  ('Mme', ' Marianne Dubois', ' Dubois'),
#  ('Mme', ' Virginie Duby-Muller', ' Duby-Muller'),
#  ('M.', ' Jean-Pierre Dufau', ' Dufau'),
#  ('Mme', ' Cécile Duflot', ' Duflot'),
#  ('Mme', ' Anne-Lise Dufour-Tonini', ' Dufour-Tonini'),
#  ('Mme', ' Françoise Dumas', ' Dumas'),
#  ('M.', ' William Dumas', ' Dumas'),
#  ('M.', ' Jean-Louis Dumont', ' Dumont'),
#  ('Mme', ' Laurence Dumont', ' Dumont'),
#  ('M.', ' Nicolas Dupont-Aignan', ' Dupont-Aignan'),
#  ('M.', ' Jean-Paul Dupré', ' Dupré'),
#  ('M.', ' Yves Durand', ' Durand'),
#  ('M.', ' Philippe Duron', ' Duron'),
#  ('M.', ' Olivier Dussopt', ' Dussopt'),
#  ('M.', ' Henri Emmanuelli', ' Emmanuelli'),
#  ('Mme', ' Corinne Erhel', ' Erhel'),
#  ('Mme', ' Sophie Errante', ' Errante'),
#  ('M.', ' Christian Estrosi', ' Estrosi'),
#  ('Mme', ' Marie-Hélène Fabre', ' Fabre'),
#  ('M.', ' Olivier Falorni', ' Falorni'),
#  ('M.', ' Daniel Fasquelle', ' Fasquelle'),
#  ('M.', ' Alain Fauré', ' Fauré'),
#  ('Mme', ' Martine Faure', ' Faure'),
#  ('M.', ' Olivier Faure', ' Faure'),
#  ('M.', ' Yannick Favennec', ' Favennec'),
#  ('M.', ' Georges Fenech', ' Fenech'),
#  ('M.', ' Hervé Féron', ' Féron'),
#  ('M.', ' Richard Ferrand', ' Ferrand'),
#  ('Mme', ' Aurélie Filippetti', ' Filippetti'),
#  ('M.', ' François Fillon', ' Fillon'),
#  ('Mme', ' Geneviève Fioraso', ' Fioraso'),
#  ('M.', ' Philippe Folliot', ' Folliot'),
#  ('Mme', ' Marie-Louise Fort', ' Fort'),
#  ('M.', ' Yves Foulon', ' Foulon'),
#  ('M.', ' Hugues Fourage', ' Fourage'),
#  ('M.', ' Jean-Marc Fournel', ' Fournel'),
#  ('Mme', ' Valérie Fourneyron', ' Fourneyron'),
#  ('Mme', ' Michèle Fournier-Armand', ' Fournier-Armand'),
#  ('M.', ' Michel Françaix', ' Françaix'),
#  ('M.', ' Marc Francina', ' Francina'),
#  ('M.', ' Christian Franqueville', ' Franqueville'),
#  ('Mme', ' Jacqueline Fraysse', ' Fraysse'),
#  ('M.', ' Jean-Christophe Fromantin', ' Fromantin'),
#  ('M.', ' Yves Fromion', ' Fromion'),
#  ('M.', ' Jean-Claude Fruteau', ' Fruteau'),
#  ('M.', ' Laurent Furst', ' Furst'),
#  ('M.', ' Jean-Louis Gagnaire', ' Gagnaire'),
#  ('Mme', ' Geneviève Gaillard', ' Gaillard'),
#  ('M.', ' Yann Galut', ' Galut'),
#  ('M.', ' Claude de Ganay', ' Ganay'),
#  ('M.', ' Sauveur Gandolfi-Scheit', ' Gandolfi-Scheit'),
#  ('M.', ' Guillaume Garot', ' Garot'),
#  ('M.', ' Hervé Gaymard', ' Gaymard'),
#  ('Mme', ' Annie Genevard', ' Genevard'),
#  ('M.', ' Guy Geoffroy', ' Geoffroy'),
#  ('Mme', ' Hélène Geoffroy', ' Geoffroy'),
#  ('M.', ' Bernard Gérard', ' Gérard'),
#  ('M.', ' Jean-Marc Germain', ' Germain'),
#  ('M.', ' Alain Gest', ' Gest'),
#  ('M.', ' Paul Giacobbi', ' Giacobbi'),
#  ('M.', ' Daniel Gibbes', ' Gibbes'),
#  ('M.', ' Franck Gilard', ' Gilard'),
#  ('M.', ' Jean-Patrick Gille', ' Gille'),
#  ('M.', ' Georges Ginesta', ' Ginesta'),
#  ('M.', ' Charles-Ange Ginesy', ' Ginesy'),
#  ('M.', ' Jean-Pierre Giran', ' Giran'),
#  ('M.', ' Joël Giraud', ' Giraud'),
#  ('M.', ' Jean Glavany', ' Glavany'),
#  ('M.', ' Yves Goasdoué', ' Goasdoué'),
#  ('M.', ' Claude Goasguen', ' Goasguen'),
#  ('M.', ' Daniel Goldberg', ' Goldberg'),
#  ('M.', ' Philippe Gomes', ' Gomes'),
#  ('M.', ' Jean-Pierre Gorges', ' Gorges'),
#  ('Mme', ' Geneviève Gosselin-Fleury', ' Gosselin-Fleury'),
#  ('M.', ' Philippe Gosselin', ' Gosselin'),
#  ('Mme', ' Pascale Got', ' Got'),
#  ('M.', ' Marc Goua', ' Goua'),
#  ('M.', ' Philippe Goujon', ' Goujon'),
#  ('Mme', ' Linda Gourjade', ' Gourjade'),
#  ('M.', ' Laurent Grandguillaume', ' Grandguillaume'),
#  ('Mme', ' Claude Greff', ' Greff'),
#  ('Mme', ' Estelle Grelier', ' Grelier'),
#  ('M.', ' Jean Grellier', ' Grellier'),
#  ('Mme', ' Anne Grommerch', ' Grommerch'),
#  ('Mme', ' Arlette Grosskost', ' Grosskost'),
#  ('M.', ' Serge Grouard', ' Grouard'),
#  ('M.', ' Henri Guaino', ' Guaino'),
#  ('Mme', ' Françoise Guégot', ' Guégot'),
#  ('Mme', ' Edith Gueugneau', ' Gueugneau'),
#  ('M.', ' Jean-Claude Guibal', ' Guibal'),
#  ('Mme', ' Élisabeth Guigou', ' Guigou'),
#  ('M.', ' Jean-Jacques Guillet', ' Guillet'),
#  ('M.', ' Christophe Guilloteau', ' Guilloteau'),
#  ('Mme', ' Chantal Guittet', ' Guittet'),
#  ('M.', ' David Habib', ' Habib'),
#  ('M.', ' Meyer Habib', ' Habib'),
#  ('M.', ' Razzy Hammadi', ' Hammadi'),
#  ('M.', ' Benoît Hamon', ' Hamon'),
#  ('M.', ' Mathieu Hanotin', ' Hanotin'),
#  ('M.', ' Michel Heinrich', ' Heinrich'),
#  ('M.', ' Michel Herbillon', ' Herbillon'),
#  ('M.', ' Antoine Herth', ' Herth'),
#  ('M.', ' Patrick Hetzel', ' Hetzel'),
#  ('M.', ' Francis Hillmeyer', ' Hillmeyer'),
#  ('Mme', ' Gilda Hobert', ' Hobert'),
#  ('M.', ' Philippe Houillon', ' Houillon'),
#  ('M.', ' Guénhaël Huet', ' Huet'),
#  ('Mme', ' Joëlle Huillier', ' Huillier'),
#  ('M.', ' Christian Hutin', ' Hutin'),
#  ('M.', ' Sébastien Huyghe', ' Huyghe'),
#  ('Mme', ' Monique Iborra', ' Iborra'),
#  ('Mme', ' Françoise Imbert', ' Imbert'),
#  ('M.', ' Michel Issindou', ' Issindou'),
#  ('M.', ' Christian Jacob', ' Jacob'),
#  ('M.', ' Denis Jacquat', ' Jacquat'),
#  ('M.', ' Éric Jalton', ' Jalton'),
#  ('M.', ' Serge Janquin', ' Janquin'),
#  ('M.', ' Yves Jégo', ' Jégo'),
#  ('M.', ' Henri Jibrayel', ' Jibrayel'),
#  ('M.', ' Régis Juanico', ' Juanico'),
#  ('M.', ' Armand Jung', ' Jung'),
#  ('M.', ' Laurent Kalinowski', ' Kalinowski'),
#  ('Mme', ' Marietta Karamanli', ' Karamanli'),
#  ('M.', ' Philippe Kemel', ' Kemel'),
#  ('M.', ' Christian Kert', ' Kert'),
#  ('Mme', ' Chaynesse Khirouni', ' Khirouni'),
#  ('Mme', ' Nathalie Kosciusko-Morizet', ' Kosciusko-Morizet'),
#  ('M.', ' Jacques Kossowski', ' Kossowski'),
#  ('M.', ' Jacques Krabal', ' Krabal'),
#  ('Mme', ' Laure de La Raudière', ' Raudière'),
#  ('M.', ' Charles de La Verpillière', ' Verpillière'),
#  ('M.', ' Patrick Labaune', ' Labaune'),
#  ('Mme', ' Bernadette Laclais', ' Laclais'),
#  ('Mme', ' Valérie Lacroute', ' Lacroute'),
#  ('Mme', ' Conchita Lacuey', ' Lacuey'),
#  ('M.', ' Marc Laffineur', ' Laffineur'),
#  ('M.', ' Jean-Christophe Lagarde', ' Lagarde'),
#  ('Mme', ' Sonia Lagarde', ' Lagarde'),
#  ('M.', ' François-Michel Lambert', ' Lambert'),
#  ('M.', ' Jérôme Lambert', ' Lambert'),
#  ('M.', ' Jacques Lamblin', ' Lamblin'),
#  ('M.', ' Jean-François Lamour', ' Lamour'),
#  ('M.', ' François Lamy', ' Lamy'),
#  ('Mme', ' Anne-Christine Lang', ' Lang'),
#  ('Mme', ' Colette Langlade', ' Langlade'),
#  ('M.', ' Guillaume Larrivé', ' Larrivé'),
#  ('M.', ' Jean Lassalle', ' Lassalle'),
#  ('M.', ' Jean Launay', ' Launay'),
#  ('M.', ' Jean-Luc Laurent', ' Laurent'),
#  ('M.', ' Thierry Lazaro', ' Lazaro'),
#  ('M.', ' Pierre-Yves Le Borgn', ' Borgn'),
#  ('M.', ' Jean-Yves Le Bouillonnec', ' Bouillonnec'),
#  ('M.', ' Gilbert Le Bris', ' Bris'),
#  ('Mme', ' Isabelle Le Callennec', ' Callennec'),
#  ('Mme', ' Anne-Yvonne Le Dain', ' Dain'),
#  ('M.', ' Jean-Yves Le Déaut', ' Déaut'),
#  ('Mme', ' Viviane Le Dissez', ' Dissez'),
#  ('M.', ' Marc Le Fur', ' Fur'),
#  ('Mme', ' Annie Le Houerou', ' Houerou'),
#  ('Mme', ' Annick Le Loch', ' Loch'),
#  ('M.', ' Bruno Le Maire', ' Maire'),
#  ('M.', ' Dominique Le Mèner', ' Mèner'),
#  ('M.', ' Philippe Le Ray', ' Ray'),
#  ('M.', ' Jean-Pierre Le Roch', ' Roch'),
#  ('M.', ' Bruno Le Roux', ' Roux'),
#  ('Mme', ' Marie Le Vern', ' Vern'),
#  ('M.', ' Alain Leboeuf', ' Leboeuf'),
#  ('M.', ' Patrick Lebreton', ' Lebreton'),
#  ('M.', ' Michel Lefait', ' Lefait'),
#  ('M.', ' Dominique Lefebvre', ' Lefebvre'),
#  ('M.', ' Frédéric Lefebvre', ' Lefebvre'),
#  ('M.', ' Pierre Lellouche', ' Lellouche'),
#  ('M.', ' Patrick Lemasle', ' Lemasle'),
#  ('Mme', ' Catherine Lemorton', ' Lemorton'),
#  ('M.', ' Christophe Léonard', ' Léonard'),
#  ('M.', ' Jean Leonetti', ' Leonetti'),
#  ('Mme', ' Annick Lepetit', ' Lepetit'),
#  ('M.', ' Pierre Lequiller', ' Lequiller'),
#  ('M.', ' Arnaud Leroy', ' Leroy'),
#  ('M.', ' Maurice Leroy', ' Leroy'),
#  ('M.', ' Michel Lesage', ' Lesage'),
#  ('M.', ' Bernard Lesterlin', ' Lesterlin'),
#  ('M.', ' Serge Letchimy', ' Letchimy'),
#  ('M.', ' Céleste Lett', ' Lett'),
#  ('Mme', ' Geneviève Levy', ' Levy'),
#  ('M.', ' Michel Liebgott', ' Liebgott'),
#  ('Mme', ' Martine Lignières-Cassou', ' Lignières-Cassou'),
#  ('Mme', ' Audrey Linkenheld', ' Linkenheld'),
#  ('M.', ' François Loncle', ' Loncle'),
#  ('Mme', ' Gabrielle Louis-Carabin', ' Louis-Carabin'),
#  ('Mme', ' Lucette Lousteau', ' Lousteau'),
#  ('Mme', ' Véronique Louwagie', ' Louwagie'),
#  ('M.', ' Lionnel Luca', ' Luca'),
#  ('M.', ' Victorin Lurel', ' Lurel'),
#  ('M.', ' Gilles Lurton', ' Lurton'),
#  ('M.', ' Jean-Pierre Maggi', ' Maggi'),
#  ('M.', ' Noël Mamère', ' Mamère'),
#  ('M.', ' Jean-François Mancel', ' Mancel'),
#  ('Mme', ' Jacqueline Maquet', ' Maquet'),
#  ('M.', ' Laurent Marcangeli', ' Marcangeli'),
#  ('Mme', ' Marie-Lou Marcel', ' Marcel'),
#  ('Mme', ' Marion Maréchal-Le Pen', ' Pen'),
#  ('M.', ' Thierry Mariani', ' Mariani'),
#  ('M.', ' Alfred Marie-Jeanne', ' Marie-Jeanne'),
#  ('M.', ' Hervé Mariton', ' Mariton'),
#  ('M.', ' Alain Marleix', ' Marleix'),
#  ('M.', ' Olivier Marleix', ' Marleix'),
#  ('M.', ' Franck Marlin', ' Marlin'),
#  ('M.', ' Jean-René Marsac', ' Marsac'),
#  ('M.', ' Alain Marsaud', ' Marsaud'),
#  ('M.', ' Philippe Martin', ' Martin'),
#  ('M.', ' Philippe Armand Martin', ' Martin'),
#  ('M.', ' Patrice Martin-Lalande', ' Martin-Lalande'),
#  ('Mme', ' Martine Martinel', ' Martinel'),
#  ('M.', ' Alain Marty', ' Marty'),
#  ('Mme', ' Frédérique Massat', ' Massat'),
#  ('Mme', ' Véronique Massonneau', ' Massonneau'),
#  ('M.', ' Jean-Claude Mathis', ' Mathis'),
#  ('Mme', ' Sandrine Mazetier', ' Mazetier'),
#  ('M.', ' François de Mazières', ' Mazières'),
#  ('M.', ' Michel Ménard', ' Ménard'),
#  ('M.', ' Patrick Mennucci', ' Mennucci'),
#  ('M.', ' Gérard Menuel', ' Menuel'),
#  ('M.', ' Damien Meslot', ' Meslot'),
#  ('M.', ' Kléber Mesquida', ' Mesquida'),
#  ('M.', ' Philippe Meunier', ' Meunier'),
#  ('M.', ' Jean-Claude Mignon', ' Mignon'),
#  ('M.', ' Jacques Moignard', ' Moignard'),
#  ('M.', ' Paul Molac', ' Molac'),
#  ('M.', ' Pierre Morange', ' Morange'),
#  ('M.', ' Yannick Moreau', ' Moreau'),
#  ('M.', ' Pierre Morel-A-L', ' Morel-A-L'),
#  ('M.', ' Hervé Morin', ' Morin'),
#  ('M.', ' Alain Moyne-Bressand', ' Moyne-Bressand'),
#  ('M.', ' Pierre-Alain Muet', ' Muet'),
#  ('M.', ' Jacques Myard', ' Myard'),
#  ('Mme', ' Dominique Nachury', ' Nachury'),
#  ('M.', ' Philippe Nauche', ' Nauche'),
#  ('M.', ' Yves Nicolin', ' Nicolin'),
#  ('Mme', ' Nathalie Nieson', ' Nieson'),
#  ('M.', ' Jean-Philippe Nilor', ' Nilor'),
#  ('M.', ' Philippe Noguès', ' Noguès'),
#  ('M.', ' Robert Olive', ' Olive'),
#  ('Mme', ' Maud Olivier', ' Olivier'),
#  ('M.', ' Patrick Ollier', ' Ollier'),
#  ('Mme', ' Dominique Orliac', ' Orliac'),
#  ('Mme', ' Monique Orphé', ' Orphé'),
#  ('M.', ' Michel Pajon', ' Pajon'),
#  ('M.', ' Bertrand Pancher', ' Pancher'),
#  ('Mme', ' Luce Pane', ' Pane'),
#  ('M.', ' Christian Paul', ' Paul'),
#  ('M.', ' Rémi Pauvros', ' Pauvros'),
#  ('Mme', ' Valérie Pécresse', ' Pécresse'),
#  ('M.', ' Germinal Peiro', ' Peiro'),
#  ('M.', ' Jacques Pélissard', ' Pélissard'),
#  ('M.', ' Hervé Pellois', ' Pellois'),
#  ('M.', ' Jean-Claude Perez', ' Perez'),
#  ('M.', ' Bernard Perrut', ' Perrut'),
#  ('M.', ' Edouard Philippe', ' Philippe'),
#  ('M.', ' Sébastien Pietrasanta', ' Pietrasanta'),
#  ('Mme', ' Christine Pires Beaune', ' Beaune'),
#  ('M.', ' Michel Piron', ' Piron'),
#  ('M.', ' Philippe Plisson', ' Plisson'),
#  ('Mme', ' Elisabeth Pochon', ' Pochon'),
#  ('M.', ' Jean-Frédéric Poisson', ' Poisson'),
#  ('Mme', ' Bérengère Poletti', ' Poletti'),
#  ('M.', ' Napole Polutélé', ' Polutélé'),
#  ('Mme', ' Barbara Pompili', ' Pompili'),
#  ('M.', ' Axel Poniatowski', ' Poniatowski'),
#  ('Mme', ' Josette Pons', ' Pons'),
#  ('M.', ' Pascal Popelin', ' Popelin'),
#  ('M.', ' Dominique Potier', ' Potier'),
#  ('M.', ' Michel Pouzol', ' Pouzol'),
#  ('Mme', ' Régine Povéda', ' Povéda'),
#  ('M.', ' Patrice Prat', ' Prat'),
#  ('M.', ' Christophe Premat', ' Premat'),
#  ('M.', ' Christophe Priou', ' Priou'),
#  ('M.', ' Joaquim Pueyo', ' Pueyo'),
#  ('M.', ' François Pupponi', ' Pupponi'),
#  ('M.', ' Didier Quentin', ' Quentin'),
#  ('Mme', ' Catherine Quéré', ' Quéré'),
#  ('Mme', ' Valérie Rabault', ' Rabault'),
#  ('Mme', ' Monique Rabin', ' Rabin'),
#  ('M.', ' Dominique Raimbourg', ' Raimbourg'),
#  ('Mme', ' Marie Récalde', ' Récalde'),
#  ('M.', ' Frédéric Reiss', ' Reiss'),
#  ('M.', ' Jean-Luc Reitzer', ' Reitzer'),
#  ('Mme', ' Marie-Line Reynaud', ' Reynaud'),
#  ('M.', ' Bernard Reynès', ' Reynès'),
#  ('M.', ' Franck Reynier', ' Reynier'),
#  ('M.', ' Pierre Ribeaud', ' Ribeaud'),
#  ('M.', ' Arnaud Richard', ' Richard'),
#  ('M.', ' Franck Riester', ' Riester'),
#  ('M.', ' Eduardo Rihan Cypel', ' Cypel'),
#  ('M.', ' Thierry Robert', ' Robert'),
#  ('M.', ' Denys Robiliard', ' Robiliard'),
#  ('M.', ' Arnaud Robinet', ' Robinet'),
#  ('M.', ' Camille de Rocca Serra', ' Serra'),
#  ('M.', ' François Rochebloine', ' Rochebloine'),
#  ('M.', ' Alain Rodet', ' Rodet'),
#  ('M.', ' Marcel Rogemont', ' Rogemont'),
#  ('Mme', ' Sophie Rohfritsch', ' Rohfritsch'),
#  ('M.', ' Frédéric Roig', ' Roig'),
#  ('Mme', ' Barbara Romagnan', ' Romagnan'),
#  ('M.', ' Bernard Roman', ' Roman'),
#  ('M.', ' Gwendal Rouillard', ' Rouillard'),
#  ('M.', ' Jean-Louis Roumegas', ' Roumegas'),
#  ('M.', ' René Rouquet', ' Rouquet'),
#  ('M.', ' Alain Rousset', ' Rousset'),
#  ('M.', ' François de Rugy', ' Rugy'),
#  ('M.', ' Martial Saddier', ' Saddier'),
#  ('Mme', ' Maina Sage', ' Sage'),
#  ('M.', ' Boinali Said', ' Said'),
#  ('M.', ' Stéphane Saint-André', ' Saint-André'),
#  ('M.', ' Paul Salen', ' Salen'),
#  ('M.', ' Rudy Salles', ' Salles'),
#  ('M.', ' Nicolas Sansu', ' Sansu'),
#  ('Mme', ' Béatrice Santais', ' Santais'),
#  ('M.', ' André Santini', ' Santini'),
#  ('Mme', ' Eva Sas', ' Sas'),
#  ('Mme', ' Odile Saugues', ' Saugues'),
#  ('M.', ' François Sauvadet', ' Sauvadet'),
#  ('M.', ' Gilbert Sauvan', ' Sauvan'),
#  ('M.', ' Gilles Savary', ' Savary'),
#  ('M.', ' François Scellier', ' Scellier'),
#  ('Mme', ' Claudine Schmid', ' Schmid'),
#  ('M.', ' André Schneider', ' Schneider'),
#  ('M.', ' Roger-Gérard Schwartzenberg', ' Schwartzenberg'),
#  ('M.', ' Gérard Sebaoun', ' Sebaoun'),
#  ('M.', ' Jean-Marie Sermier', ' Sermier'),
#  ('M.', ' Gabriel Serville', ' Serville'),
#  ('M.', ' Fernand Siré', ' Siré'),
#  ('M.', ' Christophe Sirugue', ' Sirugue'),
#  ('M.', ' Thierry Solère', ' Solère'),
#  ('Mme', ' Julie Sommaruga', ' Sommaruga'),
#  ('M.', ' Michel Sordi', ' Sordi'),
#  ('M.', ' Éric Straumann', ' Straumann'),
#  ('M.', ' Claude Sturni', ' Sturni'),
#  ('M.', ' Alain Suguenot', ' Suguenot'),
#  ('Mme', ' Michèle Tabarot', ' Tabarot'),
#  ('M.', ' Jonas Tahuaitu', ' Tahuaitu'),
#  ('Mme', ' Suzanne Tallard', ' Tallard'),
#  ('M.', ' Lionel Tardy', ' Tardy'),
#  ('M.', ' Jean-Charles Taugourdeau', ' Taugourdeau'),
#  ('M.', ' Guy Teissier', ' Teissier'),
#  ('M.', ' Pascal Terrasse', ' Terrasse'),
#  ('M.', ' Michel Terrot', ' Terrot'),
#  ('M.', ' Jean-Marie Tetart', ' Tetart'),
#  ('M.', ' Thomas Thévenoud', ' Thévenoud'),
#  ('M.', ' Dominique Tian', ' Tian'),
#  ('Mme', ' Sylvie Tolmont', ' Tolmont'),
#  ('M.', ' Jean-Louis Touraine', ' Touraine'),
#  ('M.', ' Alain Tourret', ' Tourret'),
#  ('M.', ' Stéphane Travert', ' Travert'),
#  ('Mme', ' Catherine Troallic', ' Troallic'),
#  ('M.', ' Jean-Paul Tuaiva', ' Tuaiva'),
#  ('Mme', ' Cécile Untermaier', ' Untermaier'),
#  ('M.', ' Jean-Jacques Urvoas', ' Urvoas'),
#  ('M.', ' Daniel Vaillant', ' Vaillant'),
#  ('M.', ' Jacques Valax', ' Valax'),
#  ('M.', ' François Vannson', ' Vannson'),
#  ('Mme', ' Catherine Vautrin', ' Vautrin'),
#  ('M.', ' Michel Vauzelle', ' Vauzelle'),
#  ('M.', ' Francis Vercamer', ' Vercamer'),
#  ('M.', ' Patrice Verchère', ' Verchère'),
#  ('M.', ' Fabrice Verdier', ' Verdier'),
#  ('M.', ' Michel Vergnier', ' Vergnier'),
#  ('M.', ' Arnaud Viala', ' Viala'),
#  ('M.', ' Jean-Sébastien Vialatte', ' Vialatte'),
#  ('M.', ' Jean-Pierre Vigier', ' Vigier'),
#  ('M.', ' Philippe Vigier', ' Vigier'),
#  ('M.', ' Patrick Vignal', ' Vignal'),
#  ('M.', ' François-Xavier Villain', ' Villain'),
#  ('M.', ' Jean-Michel Villaumé', ' Villaumé'),
#  ('M.', ' Philippe Vitel', ' Vitel'),
#  ('M.', ' Jean Jacques Vlody', ' Vlody'),
#  ('M.', ' Michel Voisin', ' Voisin'),
#  ('M.', ' Jean-Luc Warsmann', ' Warsmann'),
#  ('M.', ' Laurent Wauquiez', ' Wauquiez'),
#  ('M.', ' Éric Woerth', ' Woerth'),
#  ('Mme', ' Paola Zanetti', ' Zanetti'),
#  ('Mme', ' Marie-Jo Zimmermann', ' Zimmermann'),
#  ('M.',
#   ' Michel Zumkeller\nUnion des démocrates et indépendants Né le 21 janvier 1966 à Belfort',
#   ' Belfort')]

# %% [markdown]
# On voit que l'expression régulière fonctionne plutôt bien. Comptons le nombre de députés identifiés.

# %%
len(names)
# Out:
# 577

# %% [markdown]
# On a le compte pour les noms ! Passons aux dates de naissance.

# %%
birthdates = p2.findall(text)
birthdates
# Out:
# [('5 avril 1980', ' '),
#  ('17 juin 1960', ' '),
#  ('1erfévrier 1965', 'er'),
#  ('12 octobre 1959', ' '),
#  ('12 août 1945', ' '),
#  ('15 avril 1953', ' '),
#  ('1erjuillet 1945', 'er'),
#  ('7 juin 1958', ' '),
#  ('17 mars 1952', ' '),
#  ('23 avril 1956', ' '),
#  ('31 juillet 1945', ' '),
#  ('4 juillet 1952', ' '),
#  ('27 mars 1972', ' '),
#  ('19 juillet 1967', ' '),
#  ('15 décembre 1961', ' '),
#  ('24 novembre 1969', ' '),
#  ('8 juillet 1975', ' '),
#  ('3 juillet 1959', ' '),
#  ('25 mai 1970', ' '),
#  ('1erjuin 1945', 'er'),
#  ('1erseptembre 1972', 'er'),
#  ('14 novembre 1969', ' '),
#  ('11 juin 1978', ' '),
#  ('16 août 1960', ' '),
#  ('29 février 1944', ' '),
#  ('24 juillet 1942', ' '),
#  ('25 janvier 1950', ' '),
#  ('22 juillet 1961', ' '),
#  ('19 août 1973', ' '),
#  ('13 juillet 1974', ' '),
#  ('11 mars 1949', ' '),
#  ('24 octobre 1959', ' '),
#  ('24 septembre 1946', ' '),
#  ('16 août 1948', ' '),
#  ('4 février 1946', ' '),
#  ('30 août 1960', ' '),
#  ('11 novembre 1960', ' '),
#  ('6 novembre 1947', ' '),
#  ('16 avril 1967', ' '),
#  ('29 juillet 1951', ' '),
#  ('13 mai 1946', ' '),
#  ('23 mars 1973', ' '),
#  ('20 août 1956', ' '),
#  ('13 août 1965', ' '),
#  ('14 novembre 1961', ' '),
#  ('2 juin 1962', ' '),
#  ('1ermai 1977', 'er'),
#  ('10 février 1964', ' '),
#  ('19 mars 1946', ' '),
#  ('13 octobre 1962', ' '),
#  ('24 août 1950', ' '),
#  ('6 septembre 1974', ' '),
#  ('10 avril 1952', ' '),
#  ('13 septembre 1966', ' '),
#  ('11 mars 1973', ' '),
#  ('6 mai 1968', ' '),
#  ('12 septembre 1958', ' '),
#  ('21 mars 1965', ' '),
#  ('11 août 1963', ' '),
#  ('16 juin 1952', ' '),
#  ('14 janvier 1964', ' '),
#  ('30 juillet 1972', ' '),
#  ('29 août 1954', ' '),
#  ('24 novembre 1949', ' '),
#  ('12 octobre 1954', ' '),
#  ('20 décembre 1958', ' '),
#  ('4 juillet 1956', ' '),
#  ('6 mai 1946', ' '),
#  ('8 juin 1946', ' '),
#  ('24 février 1943', ' '),
#  ('15 juillet 1947', ' '),
#  ('24 mai 1946', ' '),
#  ('3 septembre 1963', ' '),
#  ('2 mai 1957', ' '),
#  ('22 septembre 1973', ' '),
#  ('13 octobre 1950', ' '),
#  ('4 mars 1969', ' '),
#  ('15 avril 1960', ' '),
#  ('21 mars 1959', ' '),
#  ('27 octobre 1964', ' '),
#  ('23 août 1953', ' '),
#  ('11 juin 1962', ' '),
#  ('26 décembre 1971', ' '),
#  ('25 novembre 1962', ' '),
#  ('26 octobre 1960', ' '),
#  ('27 décembre 1957', ' '),
#  ('7 mai 1953', ' '),
#  ('5 juin 1938', ' '),
#  ('26 mars 1966', ' '),
#  ('7 mai 1949', ' '),
#  ('27 juillet 1974', ' '),
#  ('15 septembre 1970', ' '),
#  ('14 juin 1947', ' '),
#  ('21 avril 1964', ' '),
#  ('1eroctobre 1947', 'er'),
#  ('13 juillet 1952', ' '),
#  ('30 novembre 1957', ' '),
#  ('14 août 1951', ' '),
#  ('7 mars 1945', ' '),
#  ('14 octobre 1958', ' '),
#  ('31 décembre 1975', ' '),
#  ('2 septembre 1960', ' '),
#  ('21 janvier 1952', ' '),
#  ('9 décembre 1969', ' '),
#  ('16 mars 1961', ' '),
#  ('16 mai 1980', ' '),
#  ('29 août 1948', ' '),
#  ('21 mars 1948', ' '),
#  ('15 novembre 1952', ' '),
#  ('3 janvier 1966', ' '),
#  ('21 septembre 1945', ' '),
#  ('8 février 1957', ' '),
#  ('19 février 1970', ' '),
#  ('8 février 1964', ' '),
#  ('3 janvier 1973', ' '),
#  ('6 décembre 1961', ' '),
#  ('14 octobre 1944', ' '),
#  ('9 décembre 1949', ' '),
#  ('20 mars 1962', ' '),
#  ('26 mars 1944', ' '),
#  ('25 juin 1942', ' '),
#  ('14 novembre 1966', ' '),
#  ('2 juillet 1950', ' '),
#  ('15 août 1964', ' '),
#  ('25 septembre 1944', ' '),
#  ('15 février 1958', ' '),
#  ('1erseptembre 1966', 'er'),
#  ('15 mars 1948', ' '),
#  ('27 octobre 1974', ' '),
#  ('17 mars 1975', ' '),
#  ('24 janvier 1951', ' '),
#  ('9 juillet 1955', ' '),
#  ('1ermai 1967', 'er'),
#  ('28 septembre 1965', ' '),
#  ('25 août 1948', ' '),
#  ('23 juin 1964', ' '),
#  ('31 octobre 1954', ' '),
#  ('2 mai 1948', ' '),
#  ('23 mai 1961', ' '),
#  ('22 novembre 1979', ' '),
#  ('3 février 1948', ' '),
#  ('25 juillet 1973', ' '),
#  ('5 mai 1964', ' '),
#  ('17 avril 1966', ' '),
#  ('22 mai 1958', ' '),
#  ('13 mai 1970', ' '),
#  ('17 mai 1967', ' '),
#  ('23 août 1963', ' '),
#  ('17 juillet 1953', ' '),
#  ('2 avril 1952', ' '),
#  ('28 juin 1973', ' '),
#  ('2 avril 1945', ' '),
#  ('3 janvier 1940', ' '),
#  ('16 février 1955', ' '),
#  ('29 mai 1944', ' '),
#  ('9 décembre 1968', ' '),
#  ('16 novembre 1974', ' '),
#  ('9 juin 1978', ' '),
#  ('10 janvier 1958', ' '),
#  ('31 juillet 1954', ' '),
#  ('11 octobre 1982', ' '),
#  ('1erjuin 1951', 'er'),
#  ('1eraoût 1953', 'er'),
#  ('30 septembre 1944', ' '),
#  ('19 octobre 1952', ' '),
#  ('16 octobre 1953', ' '),
#  ('11 septembre 1965', ' '),
#  ('11 juin 1937', ' '),
#  ('9 février 1956', ' '),
#  ('9 juin 1956', ' '),
#  ('12 juin 1956', ' '),
#  ('8 janvier 1947', ' '),
#  ('13 juillet 1947', ' '),
#  ('19 août 1971', ' '),
#  ('29 janvier 1960', ' '),
#  ('26 juin 1963', ' '),
#  ('14 janvier 1979', ' '),
#  ('13 octobre 1955', ' '),
#  ('24 septembre 1955', ' '),
#  ('3 mars 1951', ' '),
#  ('2 septembre 1946', ' '),
#  ('26 août 1944', ' '),
#  ('29 novembre 1960', ' '),
#  ('25 mars 1956', ' '),
#  ('21 octobre 1952', ' '),
#  ('26 décembre 1956', ' '),
#  ('1eravril 1942', 'er'),
#  ('1erseptembre 1959', 'er'),
#  ('3 août 1941', ' '),
#  ('16 mai 1961', ' '),
#  ('10 septembre 1959', ' '),
#  ('17 février 1969', ' '),
#  ('3 janvier 1958', ' '),
#  ('6 décembre 1947', ' '),
#  ('17 décembre 1957', ' '),
#  ('16 août 1979', ' '),
#  ('5 juillet 1943', ' '),
#  ('1eravril 1975', 'er'),
#  ('2 mars 1970', ' '),
#  ('12 avril 1960', ' '),
#  ('23 janvier 1942', ' '),
#  ('6 avril 1944', ' '),
#  ('2 juin 1958', ' '),
#  ('7 mars 1961', ' '),
#  ('5 février 1944', ' '),
#  ('6 juin 1946', ' '),
#  ('19 juin 1947', ' '),
#  ('16 août 1978', ' '),
#  ('31 mai 1945', ' '),
#  ('3 février 1967', ' '),
#  ('22 juillet 1971', ' '),
#  ('1erjuillet 1955', 'er'),
#  ('27 juillet 1951', ' '),
#  ('27 mars 1972', ' '),
#  ('16 janvier 1963', ' '),
#  ('1eroctobre 1962', 'er'),
#  ('30 septembre 1948', ' '),
#  ('18 août 1968', ' '),
#  ('12 août 1958', ' '),
#  ('26 octobre 1954', ' '),
#  ('3 août 1956', ' '),
#  ('1erjuillet 1962', 'er'),
#  ('17 juin 1973', ' '),
#  ('4 mars 1954', ' '),
#  ('10 octobre 1954', ' '),
#  ('14 juillet 1963', ' '),
#  ('3 décembre 1950', ' '),
#  ('10 octobre 1958', ' '),
#  ('4 juin 1965', ' '),
#  ('9 décembre 1958', ' '),
#  ('4 octobre 1959', ' '),
#  ('28 juillet 1946', ' '),
#  ('28 mai 1943', ' '),
#  ('2 février 1948', ' '),
#  ('14 mai 1949', ' '),
#  ('25 février 1947', ' '),
#  ('30 août 1962', ' '),
#  ('15 septembre 1941', ' '),
#  ('6 juin 1947', ' '),
#  ('19 mai 1965', ' '),
#  ('29 avril 1956', ' '),
#  ('13 mai 1947', ' '),
#  ('14 mars 1966', ' '),
#  ('5 septembre 1953', ' '),
#  ('19 janvier 1947', ' '),
#  ('29 mai 1966', ' '),
#  ('31 mai 1960', ' '),
#  ('7 septembre 1956', ' '),
#  ('26 mai 1949', ' '),
#  ('4 mars 1970', ' '),
#  ('29 août 1953', ' '),
#  ('12 juin 1966', ' '),
#  ('27 décembre 1950', ' '),
#  ('4 juin 1957', ' '),
#  ('8 janvier 1968', ' '),
#  ('1ernovembre 1950', 'er'),
#  ('28 janvier 1962', ' '),
#  ('8 juillet 1942', ' '),
#  ('14 mai 1956', ' '),
#  ('9 janvier 1947', ' '),
#  ('14 octobre 1959', ' '),
#  ('14 mai 1949', ' '),
#  ('22 août 1959', ' '),
#  ('12 mars 1945', ' '),
#  ('24 août 1965', ' '),
#  ('27 octobre 1958', ' '),
#  ('3 août 1953', ' '),
#  ('22 février 1954', ' '),
#  ('23 octobre 1966', ' '),
#  ('1eravril 1961', 'er'),
#  ('3 mars 1940', ' '),
#  ('30 avril 1954', ' '),
#  ('13 juillet 1962', ' '),
#  ('20 janvier 1978', ' '),
#  ('2 juin 1954', ' '),
#  ('22 juin 1973', ' '),
#  ('17 mai 1947', ' '),
#  ('11 décembre 1970', ' '),
#  ('19 juillet 1953', ' '),
#  ('19 mars 1959', ' '),
#  ('11 mars 1957', ' '),
#  ('11 août 1962', ' '),
#  ('7 juin 1953', ' '),
#  ('13 janvier 1941', ' '),
#  ('6 août 1946', ' '),
#  ('16 octobre 1946', ' '),
#  ('18 juin 1958', ' '),
#  ('12 mars 1955', ' '),
#  ('16 mars 1961', ' '),
#  ('28 avril 1961', ' '),
#  ('22 février 1979', ' '),
#  ('26 juin 1967', ' '),
#  ('22 août 1978', ' '),
#  ('15 février 1946', ' '),
#  ('6 mars 1951', ' '),
#  ('14 février 1963', ' '),
#  ('2 juillet 1964', ' '),
#  ('9 septembre 1946', ' '),
#  ('2 décembre 1948', ' '),
#  ('15 décembre 1951', ' '),
#  ('30 juillet 1956', ' '),
#  ('6 octobre 1948', ' '),
#  ('18 janvier 1961', ' '),
#  ('25 octobre 1969', ' '),
#  ('8 mars 1945', ' '),
#  ('16 septembre 1947', ' '),
#  ('12 juillet 1952', ' '),
#  ('4 décembre 1959', ' '),
#  ('29 mai 1944', ' '),
#  ('16 septembre 1961', ' '),
#  ('5 août 1943', ' '),
#  ('17 avril 1961', ' '),
#  ('18 septembre 1951', ' '),
#  ('5 février 1972', ' '),
#  ('13 décembre 1950', ' '),
#  ('28 juin 1955', ' '),
#  ('18 décembre 1964', ' '),
#  ('28 juin 1948', ' '),
#  ('25 juillet 1946', ' '),
#  ('17 mars 1968', ' '),
#  ('14 mai 1973', ' '),
#  ('11 octobre 1940', ' '),
#  ('10 avril 1948', ' '),
#  ('12 février 1965', ' '),
#  ('31 mai 1954', ' '),
#  ('13 juin 1951', ' '),
#  ('10 mars 1967', ' '),
#  ('29 octobre 1965', ' '),
#  ('30 septembre 1943', ' '),
#  ('10 août 1945', ' '),
#  ('24 octobre 1967', ' '),
#  ('29 août 1948', ' '),
#  ('24 août 1966', ' '),
#  ('7 juin 1957', ' '),
#  ('29 août 1952', ' '),
#  ('2 février 1956', ' '),
#  ('31 octobre 1959', ' '),
#  ('10 août 1961', ' '),
#  ('20 juin 1956', ' '),
#  ('24 janvier 1977', ' '),
#  ('3 mai 1955', ' '),
#  ('24 juillet 1952', ' '),
#  ('23 juin 1957', ' '),
#  ('27 septembre 1960', ' '),
#  ('4 novembre 1964', ' '),
#  ('15 septembre 1950', ' '),
#  ('3 mars 1949', ' '),
#  ('14 octobre 1966', ' '),
#  ('1erseptembre 1955', 'er'),
#  ('1erfévrier 1945', 'er'),
#  ('22 mars 1959', ' '),
#  ('28 novembre 1956', ' '),
#  ('31 mars 1960', ' '),
#  ('4 novembre 1954', ' '),
#  ('15 avril 1969', ' '),
#  ('12 novembre 1958', ' '),
#  ('16 juin 1968', ' '),
#  ('18 mars 1946', ' '),
#  ('2 mai 1965', ' '),
#  ('11 janvier 1983', ' '),
#  ('2 février 1964', ' '),
#  ('6 septembre 1963', ' '),
#  ('20 mai 1946', ' '),
#  ('7 mai 1956', ' '),
#  ('14 octobre 1963', ' '),
#  ('3 mai 1951', ' '),
#  ('18 mai 1952', ' '),
#  ('20 juin 1961', ' '),
#  ('31 janvier 1971', ' '),
#  ('9 juillet 1948', ' '),
#  ('31 mars 1958', ' '),
#  ('4 décembre 1949', ' '),
#  ('23 avril 1976', ' '),
#  ('2 février 1959', ' '),
#  ('2 juin 1952', ' '),
#  ('18 septembre 1949', ' '),
#  ('13 janvier 1953', ' '),
#  ('7 mai 1951', ' '),
#  ('24 février 1948', ' '),
#  ('15 février 1958', ' '),
#  ('22 février 1952', ' '),
#  ('11 octobre 1973', ' '),
#  ('21 octobre 1941', ' '),
#  ('20 février 1946', ' '),
#  ('20 décembre 1948', ' '),
#  ('20 mars 1961', ' '),
#  ('19 décembre 1954', ' '),
#  ('20 août 1951', ' '),
#  ('6 juillet 1963', ' '),
#  ('27 avril 1944', ' '),
#  ('25 décembre 1948', ' '),
#  ('1ermars 1948', 'er'),
#  ('13 mai 1949', ' '),
#  ('10 décembre 1980', ' '),
#  ('21 août 1953', ' '),
#  ('10 décembre 1989', ' '),
#  ('8 août 1958', ' '),
#  ('15 novembre 1936', ' '),
#  ('5 novembre 1958', ' '),
#  ('2 janvier 1946', ' '),
#  ('6 février 1971', ' '),
#  ('30 septembre 1964', ' '),
#  ('21 avril 1954', ' '),
#  ('8 mars 1949', ' '),
#  ('22 novembre 1953', ' '),
#  ('28 avril 1949', ' '),
#  ('2 décembre 1947', ' '),
#  ('26 septembre 1953', ' '),
#  ('7 mars 1946', ' '),
#  ('14 janvier 1964', ' '),
#  ('17 juillet 1959', ' '),
#  ('15 août 1939', ' '),
#  ('16 décembre 1966', ' '),
#  ('22 mai 1960', ' '),
#  ('20 mai 1961', ' '),
#  ('8 avril 1955', ' '),
#  ('7 mai 1952', ' '),
#  ('11 novembre 1964', ' '),
#  ('3 août 1945', ' '),
#  ('16 mars 1966', ' '),
#  ('2 février 1950', ' '),
#  ('8 août 1951', ' '),
#  ('21 mai 1962', ' '),
#  ('8 septembre 1956', ' '),
#  ('4 août 1975', ' '),
#  ('21 décembre 1958', ' '),
#  ('17 août 1961', ' '),
#  ('30 juillet 1945', ' '),
#  ('1erjanvier 1945', 'er'),
#  ('14 août 1947', ' '),
#  ('1erjuin 1951', 'er'),
#  ('15 juillet 1957', ' '),
#  ('5 mars 1963', ' '),
#  ('26 mars 1969', ' '),
#  ('15 mai 1965', ' '),
#  ('7 mai 1955', ' '),
#  ('16 juillet 1950', ' '),
#  ('20 février 1953', ' '),
#  ('17 décembre 1944', ' '),
#  ('15 mars 1952', ' '),
#  ('15 octobre 1964', ' '),
#  ('30 juin 1949', ' '),
#  ('5 juin 1958', ' '),
#  ('28 septembre 1955', ' '),
#  ('23 mars 1960', ' '),
#  ('1erjuillet 1952', 'er'),
#  ('14 juillet 1967', ' '),
#  ('15 septembre 1953', ' '),
#  ('20 mars 1946', ' '),
#  ('17 avril 1951', ' '),
#  ('31 mars 1964', ' '),
#  ('24 janvier 1957', ' '),
#  ('28 novembre 1970', ' '),
#  ('7 août 1977', ' '),
#  ('6 octobre 1964', ' '),
#  ('15 mars 1943', ' '),
#  ('12 janvier 1951', ' '),
#  ('19 avril 1955', ' '),
#  ('22 janvier 1963', ' '),
#  ('14 octobre 1959', ' '),
#  ('25 juin 1965', ' '),
#  ('13 juin 1975', ' '),
#  ('3 août 1951', ' '),
#  ('12 décembre 1947', ' '),
#  ('27 février 1967', ' '),
#  ('17 mars 1964', ' '),
#  ('5 juillet 1962', ' '),
#  ('24 août 1957', ' '),
#  ('28 novembre 1965', ' '),
#  ('7 décembre 1976', ' '),
#  ('2 mai 1958', ' '),
#  ('30 mai 1950', ' '),
#  ('31 juillet 1962', ' '),
#  ('23 décembre 1946', ' '),
#  ('16 mars 1948', ' '),
#  ('25 avril 1973', ' '),
#  ('2 juillet 1954', ' '),
#  ('28 avril 1950', ' '),
#  ('12 mars 1965', ' '),
#  ('12 novembre 1949', ' '),
#  ('29 décembre 1951', ' '),
#  ('17 juillet 1954', ' '),
#  ('18 octobre 1953', ' '),
#  ('20 octobre 1965', ' '),
#  ('13 juin 1955', ' '),
#  ('30 avril 1971', ' '),
#  ('3 janvier 1974', ' '),
#  ('13 novembre 1975', ' '),
#  ('1eravril 1977', 'er'),
#  ('22 juillet 1960', ' '),
#  ('30 avril 1975', ' '),
#  ('21 mai 1954', ' '),
#  ('31 octobre 1945', ' '),
#  ('4 juin 1944', ' '),
#  ('3 janvier 1948', ' '),
#  ('27 août 1962', ' '),
#  ('18 mai 1969', ' '),
#  ('25 avril 1974', ' '),
#  ('15 juillet 1952', ' '),
#  ('20 avril 1976', ' '),
#  ('6 juin 1962', ' '),
#  ('15 février 1946', ' '),
#  ('16 février 1951', ' '),
#  ('6 décembre 1973', ' '),
#  ('15 octobre 1969', ' '),
#  ('10 mai 1975', ' '),
#  ('25 septembre 1960', ' '),
#  ('21 mai 1964', ' '),
#  ('17 juin 1949', ' '),
#  ('30 juillet 1954', ' '),
#  ('17 juin 1968', ' '),
#  ('17 septembre 1964', ' '),
#  ('20 octobre 1940', ' '),
#  ('13 août 1970', ' '),
#  ('26 janvier 1943', ' '),
#  ('20 avril 1953', ' '),
#  ('15 juillet 1956', ' '),
#  ('6 décembre 1954', ' '),
#  ('7 mai 1936', ' '),
#  ('13 septembre 1955', ' '),
#  ('3 janvier 1947', ' '),
#  ('17 avril 1943', ' '),
#  ('28 novembre 1950', ' '),
#  ('5 mars 1961', ' '),
#  ('27 septembre 1959', ' '),
#  ('31 mars 1945', ' '),
#  ('14 août 1966', ' '),
#  ('17 août 1971', ' '),
#  ('1eraoût 1975', 'er'),
#  ('9 novembre 1953', ' '),
#  ('17 août 1964', ' '),
#  ('25 août 1962', ' '),
#  ('17 septembre 1951', ' '),
#  ('13 octobre 1962', ' '),
#  ('16 août 1944', ' '),
#  ('19 juin 1943', ' '),
#  ('7 juin 1966', ' '),
#  ('17 juillet 1953', ' '),
#  ('4 avril 1945', ' '),
#  ('26 octobre 1964', ' '),
#  ('18 décembre 1948', ' '),
#  ('1erseptembre 1949', 'er'),
#  ('5 mai 1974', ' '),
#  ('14 décembre 1959', ' '),
#  ('9 octobre 1962', ' '),
#  ('8 octobre 1945', ' '),
#  ('25 décembre 1947', ' '),
#  ('12 octobre 1969', ' '),
#  ('10 mai 1974', ' '),
#  ('30 octobre 1972', ' '),
#  ('28 décembre 1951', ' '),
#  ('19 septembre 1959', ' '),
#  ('19 juillet 1949', ' '),
#  ('23 août 1951', ' '),
#  ('20 octobre 1962', ' '),
#  ('26 juillet 1960', ' '),
#  ('15 août 1944', ' '),
#  ('10 mai 1958', ' '),
#  ('29 décembre 1973', ' '),
#  ('16 décembre 1968', ' '),
#  ('25 novembre 1946', ' '),
#  ('4 décembre 1974', ' '),
#  ('30 janvier 1951', ' '),
#  ('22 octobre 1969', ' '),
#  ('3 février 1958', ' '),
#  ('22 janvier 1958', ' '),
#  ('31 mai 1950', ' '),
#  ('27 mars 1946', ' '),
#  ('22 février 1955', ' '),
#  ('19 août 1967', ' '),
#  ('6 octobre 1944', ' '),
#  ('22 octobre 1965', ' '),
#  ('12 avril 1975', ' '),
#  ('29 janvier 1956', ' '),
#  ('1erseptembre 1976', 'er'),
#  ('29 avril 1951', ' '),
#  ('21 janvier 1966', ' ')]

# %%
len(birthdates)
# Out:
# 577

# %% [markdown]
# On a aussi le compte pour les dates de naissance ! On peut mettre tout ça dans une dataframe Pandas.

# %% [markdown]
# # Analyse des données à l'aide de Pandas

# %% [markdown]
# Avant de pouvoir utiliser pandas pour faire des calculs de type Excel, il nous faut encore convertir les dates de naissance, qui sont du texte, vers des objets de type date.
#
# On va utiliser [`pd.Timestamp`](http://pandas.pydata.org/pandas-docs/stable/10min.html?highlight=timestamp) pour stocker les dates au bon format. On peut donner à l'objet Timestamp des chaînes de caractère en entrée, chose que nous allons faire.

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
pd.Timestamp('2012/5/1')
# Out:
# Timestamp('2012-05-01 00:00:00')

# %% [markdown]
# Nous pouvons écire la fonction ci-dessous :

# %%
def convert2date(date_str):
    d = {'janvier': 1, 'février': 2, 'mars': 3, 'avril': 4,
         'mai': 5, 'juin': 6, 'juillet': 7, 'août': 8, 
         'septembre': 9, 'octobre': 10, 'novembre': 11, 'décembre':12}
    splits = date_str.split(' ')
    if len(splits) != 3:
        start = splits.pop(0)
        if start.startswith('1er'):
            splits.insert(0, start[3:])
            splits.insert(0, '1')
    
    
    return pd.Timestamp(splits[2] + '/' + str(d[splits[1]]) + '/' + splits[0])

# %% [markdown]
# Testons notre fonction sur notre collection de dates de naissance. Nous sélectionnons ici seulement les dates qui commencent par le 3 du mois.

# %%
[b[0] for b in birthdates if b[0].startswith('3 ')]
# Out:
# ['3 juillet 1959',
#  '3 septembre 1963',
#  '3 janvier 1966',
#  '3 janvier 1973',
#  '3 février 1948',
#  '3 janvier 1940',
#  '3 mars 1951',
#  '3 août 1941',
#  '3 janvier 1958',
#  '3 février 1967',
#  '3 août 1956',
#  '3 décembre 1950',
#  '3 août 1953',
#  '3 mars 1940',
#  '3 mai 1955',
#  '3 mars 1949',
#  '3 mai 1951',
#  '3 août 1945',
#  '3 août 1951',
#  '3 janvier 1974',
#  '3 janvier 1948',
#  '3 janvier 1947',
#  '3 février 1958']

# %% [markdown]
# Nous vérifions ci-dessous que les résultats sont pertinents :

# %%
[convert2date(b[0]) for b in birthdates if b[0].startswith('3 ')]
# Out:
# [Timestamp('1959-07-03 00:00:00'),
#  Timestamp('1963-09-03 00:00:00'),
#  Timestamp('1966-01-03 00:00:00'),
#  Timestamp('1973-01-03 00:00:00'),
#  Timestamp('1948-02-03 00:00:00'),
#  Timestamp('1940-01-03 00:00:00'),
#  Timestamp('1951-03-03 00:00:00'),
#  Timestamp('1941-08-03 00:00:00'),
#  Timestamp('1958-01-03 00:00:00'),
#  Timestamp('1967-02-03 00:00:00'),
#  Timestamp('1956-08-03 00:00:00'),
#  Timestamp('1950-12-03 00:00:00'),
#  Timestamp('1953-08-03 00:00:00'),
#  Timestamp('1940-03-03 00:00:00'),
#  Timestamp('1955-05-03 00:00:00'),
#  Timestamp('1949-03-03 00:00:00'),
#  Timestamp('1951-05-03 00:00:00'),
#  Timestamp('1945-08-03 00:00:00'),
#  Timestamp('1951-08-03 00:00:00'),
#  Timestamp('1974-01-03 00:00:00'),
#  Timestamp('1948-01-03 00:00:00'),
#  Timestamp('1947-01-03 00:00:00'),
#  Timestamp('1958-02-03 00:00:00')]

# %% [markdown]
# Nous pouvons maintenant fabriquer notre DataFrame avec l'ensemble des données :

# %%
df = pd.DataFrame(data=list(zip([n[1].split('\n')[0] for n in names], 
                           [convert2date(b[0]) for b in birthdates])), 
             columns=('Noms', 'Dates de naissance'))
df
# Out:
#                          Noms Dates de naissance
# 0                 Damien Abad         1980-04-05
# 1            Laurence Abeille         1960-06-17
# 2           Ibrahim Aboubacar         1965-02-01
# 3                  Élie Aboud         1959-10-12
# 4             Bernard Accoyer         1945-08-12
# 5               Patricia Adam         1953-04-15
# 6              Sylviane Alaux         1945-07-01
# 7                Éric Alauzet         1958-06-07
# 8              Yves Albarello         1952-03-17
# 9             Brigitte Allain         1956-04-23
# 10      Jean-Pierre Allossery         1945-07-31
# 11             Nicole Ameline         1952-07-04
# 12           Pouria Amirshahi         1972-03-27
# 13             François André         1967-07-19
# 14            Sylvie Andrieux         1961-12-15
# 15             Benoist Apparu         1969-11-24
# 16            Nathalie Appéré         1975-07-08
# 17                 Kader Arif         1959-07-03
# 18          Laurence Arribagé         1970-05-25
# 19            François Asensi         1945-06-01
# 20            Christian Assaf         1972-09-01
# 21            Isabelle Attard         1969-11-14
# 22              Julien Aubert         1978-06-11
# 23     Olivier Audibert Troin         1960-08-16
# 24             Danielle Auroi         1944-02-29
# 25             Pierre Aylagas         1942-07-24
# 26          Jean-Marc Ayrault         1950-01-25
# 27        Bruno Nestor Azerot         1961-07-22
# 28            Alexis Bachelay         1973-08-19
# 29         Guillaume Bachelay         1974-07-13
# ..                        ...                ...
# 547          Stéphane Travert         1969-10-12
# 548        Catherine Troallic         1974-05-10
# 549          Jean-Paul Tuaiva         1972-10-30
# 550         Cécile Untermaier         1951-12-28
# 551       Jean-Jacques Urvoas         1959-09-19
# 552           Daniel Vaillant         1949-07-19
# 553             Jacques Valax         1951-08-23
# 554          François Vannson         1962-10-20
# 555         Catherine Vautrin         1960-07-26
# 556           Michel Vauzelle         1944-08-15
# 557          Francis Vercamer         1958-05-10
# 558          Patrice Verchère         1973-12-29
# 559           Fabrice Verdier         1968-12-16
# 560           Michel Vergnier         1946-11-25
# 561              Arnaud Viala         1974-12-04
# 562   Jean-Sébastien Vialatte         1951-01-30
# 563        Jean-Pierre Vigier         1969-10-22
# 564           Philippe Vigier         1958-02-03
# 565            Patrick Vignal         1958-01-22
# 566   François-Xavier Villain         1950-05-31
# 567      Jean-Michel Villaumé         1946-03-27
# 568            Philippe Vitel         1955-02-22
# 569        Jean Jacques Vlody         1967-08-19
# 570             Michel Voisin         1944-10-06
# 571         Jean-Luc Warsmann         1965-10-22
# 572          Laurent Wauquiez         1975-04-12
# 573               Éric Woerth         1956-01-29
# 574             Paola Zanetti         1976-09-01
# 575       Marie-Jo Zimmermann         1951-04-29
# 576          Michel Zumkeller         1966-01-21
#
# [577 rows x 2 columns]

# %% [markdown]
# Armé de cette dataframe, nous pouvons calculer l'âge des différents députés assez facilement :

# %%
import datetime

# %%
datetime.date.today()
# Out:
# datetime.date(2016, 1, 7)

# %%
df['Âge'] = pd.Timestamp(datetime.date.today()) - df['Dates de naissance']

# %%
df
# Out:
#                          Noms Dates de naissance        Âge
# 0                 Damien Abad         1980-04-05 13060 days
# 1            Laurence Abeille         1960-06-17 20292 days
# 2           Ibrahim Aboubacar         1965-02-01 18602 days
# 3                  Élie Aboud         1959-10-12 20541 days
# 4             Bernard Accoyer         1945-08-12 25715 days
# 5               Patricia Adam         1953-04-15 22912 days
# 6              Sylviane Alaux         1945-07-01 25757 days
# 7                Éric Alauzet         1958-06-07 21033 days
# 8              Yves Albarello         1952-03-17 23306 days
# 9             Brigitte Allain         1956-04-23 21808 days
# 10      Jean-Pierre Allossery         1945-07-31 25727 days
# 11             Nicole Ameline         1952-07-04 23197 days
# 12           Pouria Amirshahi         1972-03-27 15991 days
# 13             François André         1967-07-19 17704 days
# 14            Sylvie Andrieux         1961-12-15 19746 days
# 15             Benoist Apparu         1969-11-24 16845 days
# 16            Nathalie Appéré         1975-07-08 14793 days
# 17                 Kader Arif         1959-07-03 20642 days
# 18          Laurence Arribagé         1970-05-25 16663 days
# 19            François Asensi         1945-06-01 25787 days
# 20            Christian Assaf         1972-09-01 15833 days
# 21            Isabelle Attard         1969-11-14 16855 days
# 22              Julien Aubert         1978-06-11 13724 days
# 23     Olivier Audibert Troin         1960-08-16 20232 days
# 24             Danielle Auroi         1944-02-29 26245 days
# 25             Pierre Aylagas         1942-07-24 26830 days
# 26          Jean-Marc Ayrault         1950-01-25 24088 days
# 27        Bruno Nestor Azerot         1961-07-22 19892 days
# 28            Alexis Bachelay         1973-08-19 15481 days
# 29         Guillaume Bachelay         1974-07-13 15153 days
# ..                        ...                ...        ...
# 547          Stéphane Travert         1969-10-12 16888 days
# 548        Catherine Troallic         1974-05-10 15217 days
# 549          Jean-Paul Tuaiva         1972-10-30 15774 days
# 550         Cécile Untermaier         1951-12-28 23386 days
# 551       Jean-Jacques Urvoas         1959-09-19 20564 days
# 552           Daniel Vaillant         1949-07-19 24278 days
# 553             Jacques Valax         1951-08-23 23513 days
# 554          François Vannson         1962-10-20 19437 days
# 555         Catherine Vautrin         1960-07-26 20253 days
# 556           Michel Vauzelle         1944-08-15 26077 days
# 557          Francis Vercamer         1958-05-10 21061 days
# 558          Patrice Verchère         1973-12-29 15349 days
# 559           Fabrice Verdier         1968-12-16 17188 days
# 560           Michel Vergnier         1946-11-25 25245 days
# 561              Arnaud Viala         1974-12-04 15009 days
# 562   Jean-Sébastien Vialatte         1951-01-30 23718 days
# 563        Jean-Pierre Vigier         1969-10-22 16878 days
# 564           Philippe Vigier         1958-02-03 21157 days
# 565            Patrick Vignal         1958-01-22 21169 days
# 566   François-Xavier Villain         1950-05-31 23962 days
# 567      Jean-Michel Villaumé         1946-03-27 25488 days
# 568            Philippe Vitel         1955-02-22 22234 days
# 569        Jean Jacques Vlody         1967-08-19 17673 days
# 570             Michel Voisin         1944-10-06 26025 days
# 571         Jean-Luc Warsmann         1965-10-22 18339 days
# 572          Laurent Wauquiez         1975-04-12 14880 days
# 573               Éric Woerth         1956-01-29 21893 days
# 574             Paola Zanetti         1976-09-01 14372 days
# 575       Marie-Jo Zimmermann         1951-04-29 23629 days
# 576          Michel Zumkeller         1966-01-21 18248 days
#
# [577 rows x 3 columns]

# %% [markdown]
# Le problème, c'est que l'âge est en jours, on va donc [le convertir en années](http://stackoverflow.com/questions/16103238/pandas-timedelta-in-days) :

# %%
df['Âge (années)'] = [x.days / 365 for x in df['Âge']]

# %%
df
# Out:
#                          Noms Dates de naissance        Âge  Âge (années)
# 0                 Damien Abad         1980-04-05 13060 days     35.780822
# 1            Laurence Abeille         1960-06-17 20292 days     55.594521
# 2           Ibrahim Aboubacar         1965-02-01 18602 days     50.964384
# 3                  Élie Aboud         1959-10-12 20541 days     56.276712
# 4             Bernard Accoyer         1945-08-12 25715 days     70.452055
# 5               Patricia Adam         1953-04-15 22912 days     62.772603
# 6              Sylviane Alaux         1945-07-01 25757 days     70.567123
# 7                Éric Alauzet         1958-06-07 21033 days     57.624658
# 8              Yves Albarello         1952-03-17 23306 days     63.852055
# 9             Brigitte Allain         1956-04-23 21808 days     59.747945
# 10      Jean-Pierre Allossery         1945-07-31 25727 days     70.484932
# 11             Nicole Ameline         1952-07-04 23197 days     63.553425
# 12           Pouria Amirshahi         1972-03-27 15991 days     43.810959
# 13             François André         1967-07-19 17704 days     48.504110
# 14            Sylvie Andrieux         1961-12-15 19746 days     54.098630
# 15             Benoist Apparu         1969-11-24 16845 days     46.150685
# 16            Nathalie Appéré         1975-07-08 14793 days     40.528767
# 17                 Kader Arif         1959-07-03 20642 days     56.553425
# 18          Laurence Arribagé         1970-05-25 16663 days     45.652055
# 19            François Asensi         1945-06-01 25787 days     70.649315
# 20            Christian Assaf         1972-09-01 15833 days     43.378082
# 21            Isabelle Attard         1969-11-14 16855 days     46.178082
# 22              Julien Aubert         1978-06-11 13724 days     37.600000
# 23     Olivier Audibert Troin         1960-08-16 20232 days     55.430137
# 24             Danielle Auroi         1944-02-29 26245 days     71.904110
# 25             Pierre Aylagas         1942-07-24 26830 days     73.506849
# 26          Jean-Marc Ayrault         1950-01-25 24088 days     65.994521
# 27        Bruno Nestor Azerot         1961-07-22 19892 days     54.498630
# 28            Alexis Bachelay         1973-08-19 15481 days     42.413699
# 29         Guillaume Bachelay         1974-07-13 15153 days     41.515068
# ..                        ...                ...        ...           ...
# 547          Stéphane Travert         1969-10-12 16888 days     46.268493
# 548        Catherine Troallic         1974-05-10 15217 days     41.690411
# 549          Jean-Paul Tuaiva         1972-10-30 15774 days     43.216438
# 550         Cécile Untermaier         1951-12-28 23386 days     64.071233
# 551       Jean-Jacques Urvoas         1959-09-19 20564 days     56.339726
# 552           Daniel Vaillant         1949-07-19 24278 days     66.515068
# 553             Jacques Valax         1951-08-23 23513 days     64.419178
# 554          François Vannson         1962-10-20 19437 days     53.252055
# 555         Catherine Vautrin         1960-07-26 20253 days     55.487671
# 556           Michel Vauzelle         1944-08-15 26077 days     71.443836
# 557          Francis Vercamer         1958-05-10 21061 days     57.701370
# 558          Patrice Verchère         1973-12-29 15349 days     42.052055
# 559           Fabrice Verdier         1968-12-16 17188 days     47.090411
# 560           Michel Vergnier         1946-11-25 25245 days     69.164384
# 561              Arnaud Viala         1974-12-04 15009 days     41.120548
# 562   Jean-Sébastien Vialatte         1951-01-30 23718 days     64.980822
# 563        Jean-Pierre Vigier         1969-10-22 16878 days     46.241096
# 564           Philippe Vigier         1958-02-03 21157 days     57.964384
# 565            Patrick Vignal         1958-01-22 21169 days     57.997260
# 566   François-Xavier Villain         1950-05-31 23962 days     65.649315
# 567      Jean-Michel Villaumé         1946-03-27 25488 days     69.830137
# 568            Philippe Vitel         1955-02-22 22234 days     60.915068
# 569        Jean Jacques Vlody         1967-08-19 17673 days     48.419178
# 570             Michel Voisin         1944-10-06 26025 days     71.301370
# 571         Jean-Luc Warsmann         1965-10-22 18339 days     50.243836
# 572          Laurent Wauquiez         1975-04-12 14880 days     40.767123
# 573               Éric Woerth         1956-01-29 21893 days     59.980822
# 574             Paola Zanetti         1976-09-01 14372 days     39.375342
# 575       Marie-Jo Zimmermann         1951-04-29 23629 days     64.736986
# 576          Michel Zumkeller         1966-01-21 18248 days     49.994521
#
# [577 rows x 4 columns]

# %% [markdown]
# On peut maintenant faire un joli histogramme :

# %%
# %matplotlib inline

# %%
df['Âge (années)'].hist(bins=25)
plt.xlabel('âge')
plt.ylabel('nombre de députés')

# %% [markdown]
# Les statistiques que l'on peut calculer sont :

# %%
df['Âge (années)'].describe()
# Out:
# count    577.000000
# mean      57.995898
# std        9.988493
# min       26.093151
# 25%       50.964384
# 50%       58.624658
# 75%       66.164384
# max       79.723288
# Name: Âge (années), dtype: float64

# %% [markdown]
# # Comparaison avec le restant de la France

# %% [markdown]
# On trouve sur le site de l'INSEE un lien vers des [statistiques sur l'âge de la population française en 2014](http://www.insee.fr/fr/themes/detail.asp?ref_id=bilan-demo&reg_id=0&page=donnees-detaillees/bilan-demo/pop_age2.htm).

# %%
df_pop = pd.read_excel('http://www.insee.fr/fr/ppp/bases-de-donnees/donnees-detaillees/bilan-demo/fichiers-xls/pop-1janvier-fm.xls',
                      skiprows=7,
                      header=1,
                      skipfooter=3)
df_pop
# Out:
#     Année de naissance   Âge révolu  Nombre\nd'hommes  Nombre\nde femmes  \
# 0                 2014            0            387051             370260
# 1                 2013            1            387916             370500
# 2                 2012            2            394045             376249
# 3                 2011            3            394471             380218
# 4                 2010            4            407929             388696
# 5                 2009            5            405344             386586
# 6                 2008            6            407169             389524
# 7                 2007            7            405278             386970
# 8                 2006            8            412787             394049
# 9                 2005            9            404066             386640
# 10                2004           10            402204             384465
# 11                2003           11            400289             383260
# 12                2002           12            403767             384236
# 13                2001           13            408339             390995
# 14                2000           14            417354             399436
# 15                1999           15            400215             381184
# 16                1998           16            400967             381289
# 17                1997           17            395245             375323
# 18                1996           18            396418             378272
# 19                1995           19            385463             369869
# 20                1994           20            367552             354457
# 21                1993           21            358340             348128
# 22                1992           22            372304             364953
# 23                1991           23            372851             371150
# 24                1990           24            379819             379366
# 25                1989           25            377886             381935
# 26                1988           26            379413             387338
# 27                1987           27            380395             386549
# 28                1986           28            384267             394913
# 29                1985           29            383224             393452
# ..                 ...          ...               ...                ...
# 76                1938           76            195545             249332
# 77                1937           77            186798             244132
# 78                1936           78            181433             243847
# 79                1935           79            171016             239291
# 80                1934           80            166256             240306
# 81                1933           81            151458             228378
# 82                1932           82            148284             231031
# 83                1931           83            135213             217397
# 84                1930           84            125189             211078
# 85                1929           85            107349             189472
# 86                1928           86             94475             176127
# 87                1927           87             81730             161042
# 88                1926           88             70129             147781
# 89                1925           89             59217             133111
# 90                1924           90             48109             114793
# 91                1923           91             38600              99268
# 92                1922           92             31205              85541
# 93                1921           93             24783              71112
# 94                1920           94             18943              58457
# 95                1919           95              8352              27135
# 96                1918           96              5013              18468
# 97                1917           97              2925              12820
# 98                1916           98              1808               8636
# 99                1915           99              1574               6943
# 100               1914          100              1601               7777
# 101               1913          101               847               4804
# 102               1912          102               546               3037
# 103               1911          103               362               1943
# 104               1910          104               230               1267
# 105      1909 ou avant  105 ou plus                18               1086
#
#      Ensemble
# 0      757311
# 1      758416
# 2      770294
# 3      774689
# 4      796625
# 5      791930
# 6      796693
# 7      792248
# 8      806836
# 9      790706
# 10     786669
# 11     783549
# 12     788003
# 13     799334
# 14     816790
# 15     781399
# 16     782256
# 17     770568
# 18     774690
# 19     755332
# 20     722009
# 21     706468
# 22     737257
# 23     744001
# 24     759185
# 25     759821
# 26     766751
# 27     766944
# 28     779180
# 29     776676
# ..        ...
# 76     444877
# 77     430930
# 78     425280
# 79     410307
# 80     406562
# 81     379836
# 82     379315
# 83     352610
# 84     336267
# 85     296821
# 86     270602
# 87     242772
# 88     217910
# 89     192328
# 90     162902
# 91     137868
# 92     116746
# 93      95895
# 94      77400
# 95      35487
# 96      23481
# 97      15745
# 98      10444
# 99       8517
# 100      9378
# 101      5651
# 102      3583
# 103      2305
# 104      1497
# 105      1104
#
# [106 rows x 5 columns]

# %% [markdown]
# Le nombre de français par classe d'âge est le suivant :

# %%
df_pop.plot('Âge révolu', 'Ensemble')
plt.ylabel('population')

# %% [markdown]
# Afin de pouvoir comparer la distribution des députés avec celle des français normaux, on va utiliser une méthode d'estimation par noyaux, analogue à un histogramme. Le code vient d'ici :

# %%
from scipy.stats import gaussian_kde

def kde_scipy(x, x_grid, bandwidth=0.2, **kwargs):
    """Kernel Density Estimation with Scipy"""
    # Note that scipy weights its bandwidth by the covariance of the
    # input data.  To make the results comparable to the other methods,
    # we divide the bandwidth by the sample standard deviation here.
    kde = gaussian_kde(x, bw_method=bandwidth / x.std(ddof=1), **kwargs)
    return kde.evaluate(x_grid)

# %% [markdown]
# Afin d'utiliser ce code, il nous faut transformer les données cumulées disponibles pour la population française en données ponctuelles (une série d'âges). Nous faisons ceci en prenant une certaine classe d'âge proportionnellement à un facteur de décimation.

# %%
import numpy as np

# %%
decimation_factor = 1000
french_pop_ages = []
for ind, value in enumerate(df_pop['Ensemble']):
    french_pop_ages += [ind for _ in range(int(value / decimation_factor))]

# %%
len(french_pop_ages)
# Out:
# 64152

# %% [markdown]
# On va faire les graphes sur des âges entre 0 et 100 ans.

# %%
age_grid = np.linspace(0, 100)

# %%
pop_kde = kde_scipy(np.array(french_pop_ages), age_grid, bandwidth=0.4)
dep_kde = kde_scipy(df['Âge (années)'].values, age_grid, bandwidth=0.4)

# %%
plt.plot(age_grid, 
         pop_kde, 
         label='population française')
plt.plot(age_grid, 
         dep_kde, 
         label='députés')
plt.legend(loc='upper left')
plt.xlabel('âge')
plt.ylabel('densité')

# %% [markdown]
# Ces densités étant difficiles à visualiser, on leur préfère généralement la visualisation de la fréquence cumulée, qui permet de les comparer facilement en terme de distribution :

# %%
import statsmodels.api as sm # recommended import according to the docs

ecdf_mp = sm.distributions.ECDF(df['Âge (années)'].values)
ecdf_french_pop = sm.distributions.ECDF(french_pop_ages)
y_mp = ecdf_mp(age_grid)
y_french_pop = ecdf_french_pop(age_grid)
plt.step(age_grid, y_mp, label='députés')
plt.step(age_grid, y_french_pop, label='population française')
plt.legend(loc='upper left')

# %% [markdown]
# Comme on le voit, les répartitions sont très différents : plus de députés vieux par rapport à la population, mais également moins de députés "très vieux" par rapport à cette même population.

# %% [markdown]
# On peut également calculer un "taux de représentation" à l'aide de ces valeurs : c'est-à-dire un ratio entre la densité de députés pour un certain âge et le nombre de députés de cet âge-là.

# %%
plt.plot(age_grid, dep_kde / pop_kde, label='représentation actuelle des députés')
plt.plot(age_grid, np.ones_like(age_grid), label='représentation équi-âge')
plt.legend(loc='upper left', fontsize=10)
plt.xlabel('âge')
plt.ylabel('densité')

# %% [markdown]
# On peut noter que les âges entre 50 et 70 sont surreprésentés, alors que les âges en dehors sont sous-représentés par la distribution actuelle des députés.
#
# Si l'on compare les quantiles entre la population française et les députés, on obtient :

# %%
pd.Series(french_pop_ages).describe()
# Out:
# count    64152.000000
# mean        40.538175
# std         24.030176
# min          0.000000
# 25%         20.000000
# 50%         41.000000
# 75%         59.000000
# max        105.000000
# dtype: float64

# %%
df['Âge (années)'].describe()
# Out:
# count    577.000000
# mean      57.995898
# std        9.988493
# min       26.093151
# 25%       50.964384
# 50%       58.624658
# 75%       66.164384
# max       79.723288
# Name: Âge (années), dtype: float64

# %% [markdown]
# On peut résumer ces données par le tableau suivant :
#
# | population           | âge moyen | 25% de la population a moins de | 50% a moins de  | 50% a plus de | 25% a plus de |
# |----------------------|-----------|---------------------------------|-----------------|---------------|---------------|
# | les Français         | 41 ans    | 20 ans                          | 41 ans          | 41 ans        | 59 ans        |
# | les députés français | 58 ans    | 51 ans                          | 59 ans          | 59 ans        | 66 ans        |

# %% [markdown]
# # Conclusions

# %% [markdown]
# Dans ce billet, nous avons étudié les données de l'âge disponibles pour les députés français. La distribution obtenue permet de retrouver les [histogrammes officiels](http://www.assemblee-nationale.fr/qui/xml/age.asp?legislature=14) et fournir de plus amples détails, comme par exemple la moyenne d'âge d'environ 60 ans des députés français.
#
# Dans la deuxième partie du billet, nous avons comparé la distribution des âges des députés avec celles du français moyen. On constate que les deux distributions sont assez différentes. En particulier, les jeunes (jusqu'à 40 ans environ) ne sont pas représentés dans les âges des députés, alors que les âges entre 50 et 70 sont surreprésentés (facteur entre 2 et 5).
#
# De nombreuses questions peuvent être posées au vu de ces résultats : quels sont les avantages et les inconvénients de cette distribution inégale ? Peut-on supposer qu'elle induit un biais significatif sur les décisions et les manières de penser par rapport à la population ? Existe-t-il des points sur lesquels l'expérience des députés diffère sensiblement de celle de la population (internet est un point qui me vient à l'esprit) ? Cette répartition par rapport à la population se retrouve-t-elle dans d'autres pays comparables à la France ? Comment a-t-elle évolué dans le temps (il y a 50 ans par exemple) ?
