# %% [markdown]
# There's a pattern that I first saw in Japan that I really like. It's a sort of wave pattern. One example that I found on the internet looks like this:
#
# ![wave](http://www.saffronmarigold.com/catalog/images/product_detail/pb_navy_ocean_asian_swatch_pd.jpg)
#
# In this post, I'll try to first draw it using Matplotlib and then animate it using MoviePy.

# %% [markdown]
# # The elementary pattern

# %% [markdown]
# In this section, we'll concentrate on drawing the elementary pattern that we will subsequently use to assemble the final result. First, we load our prerequisites:

# %%
# %matplotlib inline
import matplotlib as mpl
import pylab as pl

# %% [markdown]
# Below, we write a function that creates a round wedge with different colors inside:

# %%
def draw_elementary_pattern(ax, center, number_of_waves, wave_color=(0.8, 0.7, 1.0)):
    counter = 0
    for wave in range(number_of_waves)[::-1]:
        if counter % 2 == 0:
            ax.add_artist(mpl.patches.Wedge(center, 
                                        1./number_of_waves * (wave + 1), 
                                        0, 180, 
                                        width=1./number_of_waves, fc=wave_color))
        else:
            ax.add_artist(mpl.patches.Wedge(center, 
                                        1./number_of_waves * (wave + 1), 
                                        0, 180, 
                                        width=1./number_of_waves, fc='white'))
        counter += 1

# %% [markdown]
# We can test this code to see the result:

# %%
ax = pl.gca()
draw_elementary_pattern(ax, (0, 0), 3)
pl.xlim(-1, 1)
pl.ylim(-1, 1)
# Out:
# (-1, 1)

# %% [markdown]
# # Creating the wave pattern

# %% [markdown]
# Now that we have this elementary pattern, we can stack it to produce the Japanese style image that I like. The way it is laid out is interesting: we start with the upper layers and stack the lower layers on top. Also, we shift on row with respect to its neighbors.

# %%
pl.figure(figsize=(6, 5))
ax = pl.gca()
for row in range(20)[::-1]:
    for column in range(8):
        center = (column * 2 + row % 2, row/2.)
        draw_elementary_pattern(ax, center, 6)
        
pl.xlim(0, 15)
pl.ylim(1, 10)
pl.axis('off')
# Out:
# (0.0, 15.0, 1.0, 10.0)

# %% [markdown]
# That's it: we reached a visually pleasing goal! All with very few lines of code!
#
# We can also vary the number of wedges we use, or the colors.
#
# Below, we increase the number of waves.

# %%
pl.figure(figsize=(6, 5))
ax = pl.gca()
for row in range(20)[::-1]:
    for column in range(8):
        center = (column * 2 + row % 2, row/2.)
        draw_elementary_pattern(ax, center, 8)
        
pl.xlim(0, 15)
pl.ylim(1, 10)
pl.axis('off')
# Out:
# (0.0, 15.0, 1.0, 10.0)

# %% [markdown]
# What about changing the color as a function of row?

# %%
pl.figure(figsize=(6, 5))
ax = pl.gca()
for row in range(20)[::-1]:
    for column in range(8):
        center = (column * 2 + row % 2, row/2.)
        draw_elementary_pattern(ax, center, 9, wave_color=(0.8 * row/19., 0.7 * row/19., 1.0))
        
pl.xlim(0, 15)
pl.ylim(1, 10)
pl.axis('off')
# Out:
# (0.0, 15.0, 1.0, 10.0)

# %% [markdown]
# This last one produces an interesting coloring effect, which could almost be likened to the appearance of the sea.

# %% [markdown]
# # Animating the wave pattern

# %% [markdown]
# Now that we have a wave pattern, we're going to play a little bit with animations (this is made possible using the work by the great [Zulko](http://zulko.github.io/blog/2014/11/29/data-animations-with-python-and-moviepy/)).
#
# The first thing we will do below is to move the waves to the bottom of the screen. Because, erh, that's what waves do: they move!

# %%
import matplotlib.pyplot as plt
import numpy as np
from moviepy.video.io.bindings import mplfig_to_npimage
import moviepy.editor as mpy

# %%
duration = 2
fig_mpl, ax = plt.subplots(1, figsize=(6, 5), facecolor='white')

def make_frame_mpl(t):
    ax.cla()
    for row in range(20)[::-1]:
        for column in range(8):
            center = (column * 2 + row % 2, row/2. - t/duration)
            draw_elementary_pattern(ax, center, 6)
    pl.xlim(0, 13)
    pl.ylim(1, 9)
    pl.axis('off')
    return mplfig_to_npimage(fig_mpl) # RGB image of the figure

animation = mpy.VideoClip(make_frame_mpl, duration=duration)
animation.write_gif("files/circles.gif", fps=20)
# Out:
# [MoviePy] Building file files/circles.gif with imageio
# |----------| 0/41   0% [elapsed: 00:00 left: ?, ? iters/sec]
# |----------| 1/41   2% [elapsed: 00:00 left: 00:26,  1.48 iters/sec]
# |----------| 2/41   4% [elapsed: 00:01 left: 00:24,  1.58 iters/sec]
# |----------| 3/41   7% [elapsed: 00:01 left: 00:23,  1.61 iters/sec]
# |----------| 4/41   9% [elapsed: 00:02 left: 00:22,  1.62 iters/sec]
# |#---------| 5/41  12% [elapsed: 00:03 left: 00:21,  1.64 iters/sec]
# |#---------| 6/41  14% [elapsed: 00:03 left: 00:21,  1.64 iters/sec]
# |#---------| 7/41  17% [elapsed: 00:04 left: 00:20,  1.66 iters/sec]
# |#---------| 8/41  19% [elapsed: 00:04 left: 00:19,  1.68 iters/sec]
# |##--------| 9/41  21% [elapsed: 00:05 left: 00:19,  1.67 iters/sec]
# |##--------| 10/41  24% [elapsed: 00:05 left: 00:18,  1.68 iters/sec]
# |##--------| 11/41  26% [elapsed: 00:06 left: 00:17,  1.68 iters/sec]
# |##--------| 12/41  29% [elapsed: 00:07 left: 00:17,  1.67 iters/sec]
# |###-------| 13/41  31% [elapsed: 00:07 left: 00:16,  1.65 iters/sec]
# |###-------| 14/41  34% [elapsed: 00:08 left: 00:16,  1.62 iters/sec]
# |###-------| 15/41  36% [elapsed: 00:09 left: 00:16,  1.61 iters/sec]
# |###-------| 16/41  39% [elapsed: 00:09 left: 00:15,  1.62 iters/sec]
# |####------| 17/41  41% [elapsed: 00:10 left: 00:14,  1.63 iters/sec]
# |####------| 18/41  43% [elapsed: 00:11 left: 00:14,  1.63 iters/sec]
# |####------| 19/41  46% [elapsed: 00:11 left: 00:13,  1.64 iters/sec]
# |####------| 20/41  48% [elapsed: 00:12 left: 00:12,  1.64 iters/sec]
# |#####-----| 21/41  51% [elapsed: 00:12 left: 00:12,  1.64 iters/sec]
# |#####-----| 22/41  53% [elapsed: 00:13 left: 00:11,  1.65 iters/sec]
# |#####-----| 23/41  56% [elapsed: 00:13 left: 00:10,  1.65 iters/sec]
# |#####-----| 24/41  58% [elapsed: 00:14 left: 00:10,  1.65 iters/sec]
# |######----| 25/41  60% [elapsed: 00:15 left: 00:09,  1.65 iters/sec]
# |######----| 26/41  63% [elapsed: 00:15 left: 00:09,  1.65 iters/sec]
# |######----| 27/41  65% [elapsed: 00:16 left: 00:08,  1.65 iters/sec]
# |######----| 28/41  68% [elapsed: 00:16 left: 00:07,  1.65 iters/sec]
# |#######---| 29/41  70% [elapsed: 00:17 left: 00:07,  1.65 iters/sec]
# |#######---| 30/41  73% [elapsed: 00:18 left: 00:06,  1.63 iters/sec]
# |#######---| 31/41  75% [elapsed: 00:19 left: 00:06,  1.61 iters/sec]
# |#######---| 32/41  78% [elapsed: 00:20 left: 00:05,  1.60 iters/sec]
# |########--| 33/41  80% [elapsed: 00:20 left: 00:05,  1.59 iters/sec]
# |########--| 34/41  82% [elapsed: 00:21 left: 00:04,  1.57 iters/sec]
# |########--| 35/41  85% [elapsed: 00:22 left: 00:03,  1.56 iters/sec]
# |########--| 36/41  87% [elapsed: 00:23 left: 00:03,  1.55 iters/sec]
# |#########-| 37/41  90% [elapsed: 00:23 left: 00:02,  1.55 iters/sec]
# |#########-| 38/41  92% [elapsed: 00:24 left: 00:01,  1.55 iters/sec]
# |#########-| 39/41  95% [elapsed: 00:25 left: 00:01,  1.55 iters/sec]
# |#########-| 40/41  97% [elapsed: 00:25 left: 00:00,  1.55 iters/sec]

# %%
from IPython.display import Image

# %%
Image(url='./files/circles.gif')
# Out:
# <img src="./files/circles.gif"/>

# %% [markdown]
# What about if we use some oscillating pattern? First, we try with a fixed amplitude for every elementary pattern:

# %%
duration = 2
fig_mpl, ax = plt.subplots(1, figsize=(6, 5), facecolor='white')

def make_frame_mpl(t):
    ax.cla()
    for row in range(20)[::-1]:
        for column in range(8):
            center = (column * 2 + row % 2 + np.sin(2 * np.pi * t/duration), row/2. - t/duration)
            draw_elementary_pattern(ax, center, 6)
    pl.xlim(1, 13)
    pl.ylim(1, 9)
    pl.axis('off')
    return mplfig_to_npimage(fig_mpl) # RGB image of the figure

animation = mpy.VideoClip(make_frame_mpl, duration=duration)
animation.write_gif("files/circles2.gif", fps=20)
# Out:
# [MoviePy] Building file files/circles2.gif with imageio
# |----------| 0/41   0% [elapsed: 00:00 left: ?, ? iters/sec]
# |----------| 1/41   2% [elapsed: 00:00 left: 00:24,  1.64 iters/sec]
# |----------| 2/41   4% [elapsed: 00:01 left: 00:23,  1.64 iters/sec]
# |----------| 3/41   7% [elapsed: 00:01 left: 00:23,  1.64 iters/sec]
# |----------| 4/41   9% [elapsed: 00:02 left: 00:22,  1.65 iters/sec]
# |#---------| 5/41  12% [elapsed: 00:03 left: 00:21,  1.65 iters/sec]
# |#---------| 6/41  14% [elapsed: 00:03 left: 00:21,  1.64 iters/sec]
# |#---------| 7/41  17% [elapsed: 00:04 left: 00:20,  1.65 iters/sec]
# |#---------| 8/41  19% [elapsed: 00:04 left: 00:19,  1.65 iters/sec]
# |##--------| 9/41  21% [elapsed: 00:05 left: 00:19,  1.64 iters/sec]
# |##--------| 10/41  24% [elapsed: 00:06 left: 00:18,  1.64 iters/sec]
# |##--------| 11/41  26% [elapsed: 00:06 left: 00:18,  1.63 iters/sec]
# |##--------| 12/41  29% [elapsed: 00:07 left: 00:17,  1.62 iters/sec]
# |###-------| 13/41  31% [elapsed: 00:08 left: 00:17,  1.62 iters/sec]
# |###-------| 14/41  34% [elapsed: 00:08 left: 00:16,  1.63 iters/sec]
# |###-------| 15/41  36% [elapsed: 00:09 left: 00:16,  1.62 iters/sec]
# |###-------| 16/41  39% [elapsed: 00:09 left: 00:15,  1.62 iters/sec]
# |####------| 17/41  41% [elapsed: 00:10 left: 00:14,  1.62 iters/sec]
# |####------| 18/41  43% [elapsed: 00:11 left: 00:14,  1.62 iters/sec]
# |####------| 19/41  46% [elapsed: 00:11 left: 00:13,  1.62 iters/sec]
# |####------| 20/41  48% [elapsed: 00:12 left: 00:13,  1.61 iters/sec]
# |#####-----| 21/41  51% [elapsed: 00:13 left: 00:12,  1.61 iters/sec]
# |#####-----| 22/41  53% [elapsed: 00:13 left: 00:11,  1.61 iters/sec]
# |#####-----| 23/41  56% [elapsed: 00:14 left: 00:11,  1.62 iters/sec]
# |#####-----| 24/41  58% [elapsed: 00:14 left: 00:10,  1.62 iters/sec]
# |######----| 25/41  60% [elapsed: 00:15 left: 00:09,  1.62 iters/sec]
# |######----| 26/41  63% [elapsed: 00:16 left: 00:09,  1.62 iters/sec]
# |######----| 27/41  65% [elapsed: 00:16 left: 00:08,  1.63 iters/sec]
# |######----| 28/41  68% [elapsed: 00:17 left: 00:07,  1.63 iters/sec]
# |#######---| 29/41  70% [elapsed: 00:17 left: 00:07,  1.63 iters/sec]
# |#######---| 30/41  73% [elapsed: 00:18 left: 00:06,  1.63 iters/sec]
# |#######---| 31/41  75% [elapsed: 00:19 left: 00:06,  1.62 iters/sec]
# |#######---| 32/41  78% [elapsed: 00:19 left: 00:05,  1.62 iters/sec]
# |########--| 33/41  80% [elapsed: 00:20 left: 00:04,  1.62 iters/sec]
# |########--| 34/41  82% [elapsed: 00:20 left: 00:04,  1.62 iters/sec]
# |########--| 35/41  85% [elapsed: 00:21 left: 00:03,  1.62 iters/sec]
# |########--| 36/41  87% [elapsed: 00:22 left: 00:03,  1.62 iters/sec]
# |#########-| 37/41  90% [elapsed: 00:22 left: 00:02,  1.63 iters/sec]
# |#########-| 38/41  92% [elapsed: 00:23 left: 00:01,  1.63 iters/sec]
# |#########-| 39/41  95% [elapsed: 00:23 left: 00:01,  1.63 iters/sec]
# |#########-| 40/41  97% [elapsed: 00:24 left: 00:00,  1.63 iters/sec]

# %%
Image(url='./files/circles2.gif')
# Out:
# <img src="./files/circles2.gif"/>

# %% [markdown]
# This is nice, but what if we want a pattern with some oscillations that are more important in the middle of the screen?

# %%
duration = 2
fig_mpl, ax = plt.subplots(1, figsize=(6, 5), facecolor='white')

def make_frame_mpl(t):
    ax.cla()
    for row in range(20)[::-1]:
        for column in range(8):
            center = (column * 2 + row % 2 + 0.01 * np.sin(2 * np.pi * t/duration) * row * (20 - row), row/2. - t/duration)
            draw_elementary_pattern(ax, center, 6)
    pl.xlim(1, 13)
    pl.ylim(1, 9)
    pl.axis('off')
    return mplfig_to_npimage(fig_mpl) # RGB image of the figure

animation = mpy.VideoClip(make_frame_mpl, duration=duration)
animation.write_gif("files/circles3.gif", fps=20)
# Out:
# [MoviePy] Building file files/circles3.gif with imageio
# |----------| 0/41   0% [elapsed: 00:00 left: ?, ? iters/sec]
# |----------| 1/41   2% [elapsed: 00:00 left: 00:24,  1.63 iters/sec]
# |----------| 2/41   4% [elapsed: 00:01 left: 00:24,  1.60 iters/sec]
# |----------| 3/41   7% [elapsed: 00:01 left: 00:24,  1.56 iters/sec]
# |----------| 4/41   9% [elapsed: 00:02 left: 00:23,  1.59 iters/sec]
# |#---------| 5/41  12% [elapsed: 00:03 left: 00:22,  1.62 iters/sec]
# |#---------| 6/41  14% [elapsed: 00:03 left: 00:21,  1.60 iters/sec]
# |#---------| 7/41  17% [elapsed: 00:04 left: 00:21,  1.58 iters/sec]
# |#---------| 8/41  19% [elapsed: 00:05 left: 00:20,  1.57 iters/sec]
# |##--------| 9/41  21% [elapsed: 00:05 left: 00:20,  1.58 iters/sec]
# |##--------| 10/41  24% [elapsed: 00:06 left: 00:19,  1.59 iters/sec]
# |##--------| 11/41  26% [elapsed: 00:07 left: 00:19,  1.56 iters/sec]
# |##--------| 12/41  29% [elapsed: 00:07 left: 00:18,  1.54 iters/sec]
# |###-------| 13/41  31% [elapsed: 00:08 left: 00:18,  1.54 iters/sec]
# |###-------| 14/41  34% [elapsed: 00:09 left: 00:17,  1.53 iters/sec]
# |###-------| 15/41  36% [elapsed: 00:09 left: 00:16,  1.53 iters/sec]
# |###-------| 16/41  39% [elapsed: 00:10 left: 00:16,  1.53 iters/sec]
# |####------| 17/41  41% [elapsed: 00:11 left: 00:15,  1.53 iters/sec]
# |####------| 18/41  43% [elapsed: 00:11 left: 00:14,  1.53 iters/sec]
# |####------| 19/41  46% [elapsed: 00:12 left: 00:14,  1.54 iters/sec]
# |####------| 20/41  48% [elapsed: 00:12 left: 00:13,  1.55 iters/sec]
# |#####-----| 21/41  51% [elapsed: 00:13 left: 00:12,  1.55 iters/sec]
# |#####-----| 22/41  53% [elapsed: 00:14 left: 00:12,  1.55 iters/sec]
# |#####-----| 23/41  56% [elapsed: 00:14 left: 00:11,  1.56 iters/sec]
# |#####-----| 24/41  58% [elapsed: 00:15 left: 00:10,  1.56 iters/sec]
# |######----| 25/41  60% [elapsed: 00:16 left: 00:10,  1.56 iters/sec]
# |######----| 26/41  63% [elapsed: 00:16 left: 00:09,  1.56 iters/sec]
# |######----| 27/41  65% [elapsed: 00:17 left: 00:08,  1.56 iters/sec]
# |######----| 28/41  68% [elapsed: 00:17 left: 00:08,  1.57 iters/sec]
# |#######---| 29/41  70% [elapsed: 00:18 left: 00:07,  1.57 iters/sec]
# |#######---| 30/41  73% [elapsed: 00:19 left: 00:07,  1.57 iters/sec]
# |#######---| 31/41  75% [elapsed: 00:19 left: 00:06,  1.57 iters/sec]
# |#######---| 32/41  78% [elapsed: 00:20 left: 00:05,  1.58 iters/sec]
# |########--| 33/41  80% [elapsed: 00:20 left: 00:05,  1.58 iters/sec]
# |########--| 34/41  82% [elapsed: 00:21 left: 00:04,  1.58 iters/sec]
# |########--| 35/41  85% [elapsed: 00:22 left: 00:03,  1.58 iters/sec]
# |########--| 36/41  87% [elapsed: 00:22 left: 00:03,  1.59 iters/sec]
# |#########-| 37/41  90% [elapsed: 00:23 left: 00:02,  1.59 iters/sec]
# |#########-| 38/41  92% [elapsed: 00:23 left: 00:01,  1.59 iters/sec]
# |#########-| 39/41  95% [elapsed: 00:24 left: 00:01,  1.59 iters/sec]
# |#########-| 40/41  97% [elapsed: 00:25 left: 00:00,  1.59 iters/sec]

# %%
Image(url='./files/circles3.gif')
# Out:
# <img src="./files/circles3.gif"/>

# %% [markdown]
# Another idea is to play with the colors:

# %%
duration = 2
fig_mpl, ax = plt.subplots(1, figsize=(6, 5), facecolor='white')

def make_frame_mpl(t):
    ax.cla()
    for row in range(20)[::-1]:
        for column in range(8):
            center = (column * 2 + row % 2, row/2. - t/duration)
            draw_elementary_pattern(ax, center, 9, 
                                    wave_color=(0.8 * np.abs(np.sin(2 * np.pi * 0.5 * t/duration - 2 * row/19.)),
                                                0.7 * np.abs(np.sin(2 * np.pi * 0.5 * t/duration - column/7.)),
                                                1.0))
    pl.xlim(1, 13)
    pl.ylim(1, 9)
    pl.axis('off')
    return mplfig_to_npimage(fig_mpl) # RGB image of the figure

animation = mpy.VideoClip(make_frame_mpl, duration=duration)
animation.write_gif("files/circles4.gif", fps=20)
# Out:
# [MoviePy] Building file files/circles4.gif with imageio
# |----------| 0/41   0% [elapsed: 00:00 left: ?, ? iters/sec]
# |----------| 1/41   2% [elapsed: 00:00 left: 00:38,  1.03 iters/sec]
# |----------| 2/41   4% [elapsed: 00:01 left: 00:38,  1.00 iters/sec]
# |----------| 3/41   7% [elapsed: 00:02 left: 00:37,  1.02 iters/sec]
# |----------| 4/41   9% [elapsed: 00:04 left: 00:37,  1.00 iters/sec]
# |#---------| 5/41  12% [elapsed: 00:05 left: 00:36,  1.00 iters/sec]
# |#---------| 6/41  14% [elapsed: 00:05 left: 00:34,  1.02 iters/sec]
# |#---------| 7/41  17% [elapsed: 00:06 left: 00:33,  1.03 iters/sec]
# |#---------| 8/41  19% [elapsed: 00:07 left: 00:31,  1.03 iters/sec]
# |##--------| 9/41  21% [elapsed: 00:08 left: 00:30,  1.04 iters/sec]
# |##--------| 10/41  24% [elapsed: 00:09 left: 00:29,  1.05 iters/sec]
# |##--------| 11/41  26% [elapsed: 00:10 left: 00:28,  1.05 iters/sec]
# |##--------| 12/41  29% [elapsed: 00:11 left: 00:27,  1.05 iters/sec]
# |###-------| 13/41  31% [elapsed: 00:12 left: 00:26,  1.06 iters/sec]
# |###-------| 14/41  34% [elapsed: 00:13 left: 00:25,  1.06 iters/sec]
# |###-------| 15/41  36% [elapsed: 00:14 left: 00:24,  1.06 iters/sec]
# |###-------| 16/41  39% [elapsed: 00:15 left: 00:23,  1.05 iters/sec]
# |####------| 17/41  41% [elapsed: 00:16 left: 00:23,  1.03 iters/sec]
# |####------| 18/41  43% [elapsed: 00:17 left: 00:22,  1.01 iters/sec]
# |####------| 19/41  46% [elapsed: 00:18 left: 00:21,  1.00 iters/sec]
# |####------| 20/41  48% [elapsed: 00:20 left: 00:21,  0.99 iters/sec]
# |#####-----| 21/41  51% [elapsed: 00:21 left: 00:20,  0.99 iters/sec]
# |#####-----| 22/41  53% [elapsed: 00:22 left: 00:19,  0.98 iters/sec]
# |#####-----| 23/41  56% [elapsed: 00:23 left: 00:18,  0.98 iters/sec]
# |#####-----| 24/41  58% [elapsed: 00:24 left: 00:17,  0.97 iters/sec]
# |######----| 25/41  60% [elapsed: 00:25 left: 00:16,  0.97 iters/sec]
# |######----| 26/41  63% [elapsed: 00:27 left: 00:15,  0.96 iters/sec]
# |######----| 27/41  65% [elapsed: 00:28 left: 00:14,  0.96 iters/sec]
# |######----| 28/41  68% [elapsed: 00:29 left: 00:13,  0.95 iters/sec]
# |#######---| 29/41  70% [elapsed: 00:30 left: 00:12,  0.95 iters/sec]
# |#######---| 30/41  73% [elapsed: 00:31 left: 00:11,  0.95 iters/sec]
# |#######---| 31/41  75% [elapsed: 00:32 left: 00:10,  0.94 iters/sec]
# |#######---| 32/41  78% [elapsed: 00:34 left: 00:09,  0.94 iters/sec]
# |########--| 33/41  80% [elapsed: 00:35 left: 00:08,  0.94 iters/sec]
# |########--| 34/41  82% [elapsed: 00:36 left: 00:07,  0.94 iters/sec]
# |########--| 35/41  85% [elapsed: 00:37 left: 00:06,  0.94 iters/sec]
# |########--| 36/41  87% [elapsed: 00:37 left: 00:05,  0.95 iters/sec]
# |#########-| 37/41  90% [elapsed: 00:38 left: 00:04,  0.95 iters/sec]
# |#########-| 38/41  92% [elapsed: 00:39 left: 00:03,  0.95 iters/sec]
# |#########-| 39/41  95% [elapsed: 00:40 left: 00:02,  0.96 iters/sec]
# |#########-| 40/41  97% [elapsed: 00:41 left: 00:01,  0.96 iters/sec]

# %%
Image(url='./files/circles4.gif')
# Out:
# <img src="./files/circles4.gif"/>

# %% [markdown]
# There are many more variations that could be obtained using this basic wave pattern. If you're interested, download this notebook and have fun by trying it out for yourself!

# %% [markdown]
# # Conclusion

# %% [markdown]
# I hope you liked these simple animations using Matplotlib and Moviepy. As you have seen, you don't necessarily need a lot of things to create interesting visualizations. And the nicest thing is that this can be done using very few lines of code.
#
# This post was entirely written using the IPython notebook. You can see a static view or download this notebook with the help of nbviewer at [20150225_JapanesePattern.ipynb](http://nbviewer.ipython.org/urls/raw.github.com/flothesof/posts/master/20150225_JapanesePattern.ipynb).
